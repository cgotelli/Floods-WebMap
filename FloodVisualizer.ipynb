# %% [markdown]
# # Automatización Iber 3.3.1

# %% [markdown]
# Comenzamos con la modificación del modelo para el cambio automático de la condición de borde de entrada. Esto incluye la modificación de la CB, el remallado, la asignación de elevación para cada nodo

# %%
import pandas as pd

# Definir el directorio del proyecto (ajustar según sea necesario)
project_directory = "C:/temp/cruce_test.gid"

# Definir el archivo batch donde se guardarán los comandos
batch_file = "instructions.bch"

# Función para escribir en el archivo batch
def write_to_batch(commands):
    with open(batch_file, "w") as f:
        for command in commands:
            f.write(command + "\n")

# 1. Cargar el archivo del proyecto
load_project_command = f"MEscape Files Read {{{project_directory}}}"

# 2. Modificar la condición de borde (función de generación del comando)
def load_hydrograph(file_path="G:/Floods-WebMap/hydrograph.csv"):
    try:
        df = pd.read_csv(file_path, header=None, delim_whitespace=True)
        df.columns = ["Tiempo", "Caudal"]
        return df
    except Exception as e:
        print(f"Error al leer el archivo: {e}")
        return None

def generate_boundary_condition_command(face_number, df):
    if df is None or df.empty:
        return "Error: No se han cargado datos del hidrograma."
    
    hydrograph_str = " ".join([f"{row['Tiempo']} {row['Caudal']}" for _, row in df.iterrows()])
    
    command = f"Mescape Data Conditions AssignCond 2D_Inlet Change 0 {{0 0 0}} Total_Discharge Critical/Subcritical #N# 8 {hydrograph_str} #N# 3 0.0 0.0 0.0 1 _Subcritical #N# 2 0.0 0.0 Elevation #N# 3 0.0 0.0 0.0 #N# 3 0.0 0.0 0.0 #N# 2 0.0 0.0 #N# 1 0.0 {face_number} escape"
    
    return command

# Leer el hidrograma y generar el comando
df_hydrograph = load_hydrograph()
boundary_condition_command = generate_boundary_condition_command(2, df_hydrograph)  # Número de cara por defecto: 2

# 3. Generar la malla
meshing_commands = [
    "Mescape Meshing Generate Yes {-tcl- GiD_RaiseEvent GiD_Event_BeforeMeshGeneration 0.551582} escape",
    "Mescape Utilities SwapNormals Surfaces SelByNormal 1:end escape 0.0 0.0 1.0 Yes escape",
    "Mescape Meshing Generate 0.551582 MeshingParametersFrom=Preferences escape 'SetViewMode Mesh"
]

# Escribir los comandos en el archivo batch
all_commands = [load_project_command, boundary_condition_command] + meshing_commands
write_to_batch(all_commands)

print(f"Archivo batch '{batch_file}' generado con éxito en el directorio actual.")
# Out:
# Archivo batch 'instructions.bch' generado con éxito en el directorio actual.
# C:\Users\EPFL-LHE\AppData\Local\Temp\ipykernel_23432\94994252.py:21: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, header=None, delim_whitespace=True)

# %% [markdown]
# Una vez creado el proyecto, en vez de correr el caso desde la consola batch, preferimos llamar al solver de IberPlus directamente. Así podremos hacer uso de CUDA para acelerar el cálculo.

# %%
import os
import sys
import subprocess

# Ruta del ejecutable de Iber (ajústala según la instalación)
iber_exe = r'C:\Program Files\Iber\Iber 3.3.1\problemtypes\IBER.gid\bin\windows\IberPlus.exe'  

# Lista de modelos Iber a ejecutar (definida como lista por si se necesitan varios)
modelos_iber = [r'C:\temp\cruce_test.gid']  # Agregar más modelos si es necesario

print("\tEjecutando modelos Iber:")

for i, modelo in enumerate(modelos_iber, start=1):
    os.chdir(modelo)  # Cambia al directorio del modelo
    print(f"\r\tEjecutando {i}/{len(modelos_iber)}: {modelo}")

    # Llamar al ejecutable de Iber
    subprocess.call(iber_exe)

    print("\tModelo completado.")

print("\nTodos los modelos han sido ejecutados.")
# Out:
# 	Ejecutando modelos Iber:
# 	Ejecutando 1/1: C:\temp\cruce_test.gid
# 	Modelo completado.
#
# Todos los modelos han sido ejecutados.

# %%
import os
import subprocess

# Definir el archivo batch para el postproceso
postprocess_batch_file = "postprocess.bch"

# Crear el contenido del archivo batch para el postproceso
postprocess_commands = f"""MEscape Files Read {{{project_directory}}}
Mescape Postprocess escape
*****tcl set ::Reproject 0
*****tcl set ::Interpolation linear
*****tcl set ::cell 0.1
*****tcl set ::Timeresults Allsteps
*****tcl set ::PostRaster(thisanalysis) Hydraulic
*****tcl set ::PostRaster(thisstep) =
*****tcl set ::PostRaster(over) elements
*****tcl set ::PostRaster(thiszone) 1
*****tcl set ::PostRaster(thishemis) N
*****tcl set ::PostRaster(output,number) 1
*****tcl set "::PostRaster(output,Depth (m))" 1
*****tcl set ::PostRaster(output,Froude) 0
*****tcl set ::PostRaster(output,connectivities) 0
*****tcl set "::PostRaster(output,Water Elevation (m))" 0
*****tcl set "::PostRaster(output,Specific Discharge (m2/s))" 0
*****tcl set ::PostRaster(output,coordinates) 0
*****tcl set "::PostRaster(output,Velocity (m/s))" 1
*****tcl ::PostRaster::ApplyListEntities nada
MEscape Quit No
"""

# Guardar el archivo batch en la misma carpeta que el otro batch
with open(postprocess_batch_file, "w") as f:
    f.write(postprocess_commands)

print(f"Archivo batch '{postprocess_batch_file}' generado con éxito.")

# Ruta del ejecutable de Iber
iber_gui_exe = r"C:\Program Files\Iber\Iber 3.3.1\gid.exe"

# Comando para ejecutar el postproceso en Iber
command = [iber_gui_exe, "-b", os.path.abspath(postprocess_batch_file), "-n"]

# Ejecutar el postproceso
print("\nEjecutando el postproceso en Iber...")
subprocess.run(command)

print("\nPostproceso completado.")
# Out:
# Archivo batch 'postprocess.bch' generado con éxito.
#
# Ejecutando el postproceso en Iber...
#
# Postproceso completado.

# %%
import os
import re

# Directorio donde se guardan los archivos ASC
asc_directory = r"C:\temp\cruce_test.gid\Rasters\Hydraulic"

# Expresión regular para detectar archivos con formato Depth____X.X.asc o Depth____X.asc
pattern = re.compile(r"Depth____(\d+)(?:\.\d+)?\.asc")

# Renombrar archivos
for filename in os.listdir(asc_directory):
    match = pattern.match(filename)
    if match:
        original_number = int(float(match.group(1)))  # Convertir a entero eliminando decimales
        new_number = f"{original_number:06d}"  # Convertir a 6 cifras con ceros a la izquierda
        new_filename = f"Depth____{new_number}.asc"
        old_path = os.path.join(asc_directory, filename)
        new_path = os.path.join(asc_directory, new_filename)
        
        # Renombrar el archivo
        os.rename(old_path, new_path)
        print(f"Renombrado: {filename} → {new_filename}")

print("\nTodos los archivos han sido renombrados correctamente.")
# Out:
# Renombrado: Depth____0.0.asc → Depth____000000.asc
# Renombrado: Depth____1.0.asc → Depth____000001.asc
# Renombrado: Depth____10.0.asc → Depth____000010.asc
# Renombrado: Depth____100.0.asc → Depth____000100.asc
# Renombrado: Depth____101.0.asc → Depth____000101.asc
# Renombrado: Depth____102.0.asc → Depth____000102.asc
# Renombrado: Depth____103.0.asc → Depth____000103.asc
# Renombrado: Depth____104.0.asc → Depth____000104.asc
# Renombrado: Depth____105.0.asc → Depth____000105.asc
# Renombrado: Depth____106.0.asc → Depth____000106.asc
# Renombrado: Depth____107.0.asc → Depth____000107.asc
# Renombrado: Depth____108.0.asc → Depth____000108.asc
# Renombrado: Depth____109.0.asc → Depth____000109.asc
# Renombrado: Depth____11.0.asc → Depth____000011.asc
# Renombrado: Depth____110.0.asc → Depth____000110.asc
# Renombrado: Depth____111.0.asc → Depth____000111.asc
# Renombrado: Depth____112.0.asc → Depth____000112.asc
# Renombrado: Depth____113.0.asc → Depth____000113.asc
# Renombrado: Depth____114.0.asc → Depth____000114.asc
# Renombrado: Depth____115.0.asc → Depth____000115.asc
# Renombrado: Depth____116.0.asc → Depth____000116.asc
# Renombrado: Depth____117.0.asc → Depth____000117.asc
# Renombrado: Depth____118.0.asc → Depth____000118.asc
# Renombrado: Depth____119.0.asc → Depth____000119.asc
# Renombrado: Depth____12.0.asc → Depth____000012.asc
# Renombrado: Depth____120.0.asc → Depth____000120.asc
# Renombrado: Depth____121.0.asc → Depth____000121.asc
# Renombrado: Depth____122.0.asc → Depth____000122.asc
# Renombrado: Depth____123.0.asc → Depth____000123.asc
# Renombrado: Depth____124.0.asc → Depth____000124.asc
# Renombrado: Depth____125.0.asc → Depth____000125.asc
# Renombrado: Depth____126.0.asc → Depth____000126.asc
# Renombrado: Depth____127.0.asc → Depth____000127.asc
# Renombrado: Depth____128.0.asc → Depth____000128.asc
# Renombrado: Depth____129.0.asc → Depth____000129.asc
# Renombrado: Depth____13.0.asc → Depth____000013.asc
# Renombrado: Depth____130.0.asc → Depth____000130.asc
# Renombrado: Depth____131.0.asc → Depth____000131.asc
# Renombrado: Depth____132.0.asc → Depth____000132.asc
# Renombrado: Depth____133.0.asc → Depth____000133.asc
# Renombrado: Depth____134.0.asc → Depth____000134.asc
# Renombrado: Depth____135.0.asc → Depth____000135.asc
# Renombrado: Depth____136.0.asc → Depth____000136.asc
# Renombrado: Depth____137.0.asc → Depth____000137.asc
# Renombrado: Depth____138.0.asc → Depth____000138.asc
# Renombrado: Depth____139.0.asc → Depth____000139.asc
# Renombrado: Depth____14.0.asc → Depth____000014.asc
# Renombrado: Depth____140.0.asc → Depth____000140.asc
# Renombrado: Depth____141.0.asc → Depth____000141.asc
# Renombrado: Depth____142.0.asc → Depth____000142.asc
# Renombrado: Depth____143.0.asc → Depth____000143.asc
# Renombrado: Depth____144.0.asc → Depth____000144.asc
# Renombrado: Depth____145.0.asc → Depth____000145.asc
# Renombrado: Depth____146.0.asc → Depth____000146.asc
# Renombrado: Depth____147.0.asc → Depth____000147.asc
# Renombrado: Depth____148.0.asc → Depth____000148.asc
# Renombrado: Depth____149.0.asc → Depth____000149.asc
# Renombrado: Depth____15.0.asc → Depth____000015.asc
# Renombrado: Depth____150.0.asc → Depth____000150.asc
# Renombrado: Depth____151.0.asc → Depth____000151.asc
# Renombrado: Depth____152.0.asc → Depth____000152.asc
# Renombrado: Depth____153.0.asc → Depth____000153.asc
# Renombrado: Depth____154.0.asc → Depth____000154.asc
# Renombrado: Depth____155.0.asc → Depth____000155.asc
# Renombrado: Depth____156.0.asc → Depth____000156.asc
# Renombrado: Depth____157.0.asc → Depth____000157.asc
# Renombrado: Depth____158.0.asc → Depth____000158.asc
# Renombrado: Depth____159.0.asc → Depth____000159.asc
# Renombrado: Depth____16.0.asc → Depth____000016.asc
# Renombrado: Depth____160.0.asc → Depth____000160.asc
# Renombrado: Depth____161.0.asc → Depth____000161.asc
# Renombrado: Depth____162.0.asc → Depth____000162.asc
# Renombrado: Depth____163.0.asc → Depth____000163.asc
# Renombrado: Depth____164.0.asc → Depth____000164.asc
# Renombrado: Depth____165.0.asc → Depth____000165.asc
# Renombrado: Depth____166.0.asc → Depth____000166.asc
# Renombrado: Depth____167.0.asc → Depth____000167.asc
# Renombrado: Depth____168.0.asc → Depth____000168.asc
# Renombrado: Depth____169.0.asc → Depth____000169.asc
# Renombrado: Depth____17.0.asc → Depth____000017.asc
# Renombrado: Depth____170.0.asc → Depth____000170.asc
# Renombrado: Depth____171.0.asc → Depth____000171.asc
# Renombrado: Depth____172.0.asc → Depth____000172.asc
# Renombrado: Depth____173.0.asc → Depth____000173.asc
# Renombrado: Depth____174.0.asc → Depth____000174.asc
# Renombrado: Depth____175.0.asc → Depth____000175.asc
# Renombrado: Depth____176.0.asc → Depth____000176.asc
# Renombrado: Depth____177.0.asc → Depth____000177.asc
# Renombrado: Depth____178.0.asc → Depth____000178.asc
# Renombrado: Depth____179.0.asc → Depth____000179.asc
# Renombrado: Depth____18.0.asc → Depth____000018.asc
# Renombrado: Depth____180.0.asc → Depth____000180.asc
# Renombrado: Depth____181.0.asc → Depth____000181.asc
# Renombrado: Depth____182.0.asc → Depth____000182.asc
# Renombrado: Depth____183.0.asc → Depth____000183.asc
# Renombrado: Depth____184.0.asc → Depth____000184.asc
# Renombrado: Depth____185.0.asc → Depth____000185.asc
# Renombrado: Depth____186.0.asc → Depth____000186.asc
# Renombrado: Depth____187.0.asc → Depth____000187.asc
# Renombrado: Depth____188.0.asc → Depth____000188.asc
# Renombrado: Depth____189.0.asc → Depth____000189.asc
# Renombrado: Depth____19.0.asc → Depth____000019.asc
# Renombrado: Depth____190.0.asc → Depth____000190.asc
# Renombrado: Depth____191.0.asc → Depth____000191.asc
# Renombrado: Depth____192.0.asc → Depth____000192.asc
# Renombrado: Depth____193.0.asc → Depth____000193.asc
# Renombrado: Depth____194.0.asc → Depth____000194.asc
# Renombrado: Depth____195.0.asc → Depth____000195.asc
# Renombrado: Depth____196.0.asc → Depth____000196.asc
# Renombrado: Depth____197.0.asc → Depth____000197.asc
# Renombrado: Depth____198.0.asc → Depth____000198.asc
# Renombrado: Depth____199.0.asc → Depth____000199.asc
# Renombrado: Depth____2.0.asc → Depth____000002.asc
# Renombrado: Depth____20.0.asc → Depth____000020.asc
# Renombrado: Depth____200.0.asc → Depth____000200.asc
# Renombrado: Depth____201.0.asc → Depth____000201.asc
# Renombrado: Depth____202.0.asc → Depth____000202.asc
# Renombrado: Depth____203.0.asc → Depth____000203.asc
# Renombrado: Depth____204.0.asc → Depth____000204.asc
# Renombrado: Depth____205.0.asc → Depth____000205.asc
# Renombrado: Depth____206.0.asc → Depth____000206.asc
# Renombrado: Depth____207.0.asc → Depth____000207.asc
# Renombrado: Depth____208.0.asc → Depth____000208.asc
# Renombrado: Depth____209.0.asc → Depth____000209.asc
# Renombrado: Depth____21.0.asc → Depth____000021.asc
# Renombrado: Depth____210.0.asc → Depth____000210.asc
# Renombrado: Depth____211.0.asc → Depth____000211.asc
# Renombrado: Depth____212.0.asc → Depth____000212.asc
# Renombrado: Depth____213.0.asc → Depth____000213.asc
# Renombrado: Depth____214.0.asc → Depth____000214.asc
# Renombrado: Depth____215.0.asc → Depth____000215.asc
# Renombrado: Depth____216.0.asc → Depth____000216.asc
# Renombrado: Depth____217.0.asc → Depth____000217.asc
# Renombrado: Depth____218.0.asc → Depth____000218.asc
# Renombrado: Depth____219.0.asc → Depth____000219.asc
# Renombrado: Depth____22.0.asc → Depth____000022.asc
# Renombrado: Depth____220.0.asc → Depth____000220.asc
# Renombrado: Depth____221.0.asc → Depth____000221.asc
# Renombrado: Depth____222.0.asc → Depth____000222.asc
# Renombrado: Depth____223.0.asc → Depth____000223.asc
# Renombrado: Depth____224.0.asc → Depth____000224.asc
# Renombrado: Depth____225.0.asc → Depth____000225.asc
# Renombrado: Depth____226.0.asc → Depth____000226.asc
# Renombrado: Depth____227.0.asc → Depth____000227.asc
# Renombrado: Depth____228.0.asc → Depth____000228.asc
# Renombrado: Depth____229.0.asc → Depth____000229.asc
# Renombrado: Depth____23.0.asc → Depth____000023.asc
# Renombrado: Depth____230.0.asc → Depth____000230.asc
# Renombrado: Depth____231.0.asc → Depth____000231.asc
# Renombrado: Depth____232.0.asc → Depth____000232.asc
# Renombrado: Depth____233.0.asc → Depth____000233.asc
# Renombrado: Depth____234.0.asc → Depth____000234.asc
# Renombrado: Depth____235.0.asc → Depth____000235.asc
# Renombrado: Depth____236.0.asc → Depth____000236.asc
# Renombrado: Depth____237.0.asc → Depth____000237.asc
# Renombrado: Depth____238.0.asc → Depth____000238.asc
# Renombrado: Depth____239.0.asc → Depth____000239.asc
# Renombrado: Depth____24.0.asc → Depth____000024.asc
# Renombrado: Depth____240.0.asc → Depth____000240.asc
# Renombrado: Depth____241.0.asc → Depth____000241.asc
# Renombrado: Depth____242.0.asc → Depth____000242.asc
# Renombrado: Depth____243.0.asc → Depth____000243.asc
# Renombrado: Depth____244.0.asc → Depth____000244.asc
# Renombrado: Depth____245.0.asc → Depth____000245.asc
# Renombrado: Depth____246.0.asc → Depth____000246.asc
# Renombrado: Depth____247.0.asc → Depth____000247.asc
# Renombrado: Depth____248.0.asc → Depth____000248.asc
# Renombrado: Depth____249.0.asc → Depth____000249.asc
# Renombrado: Depth____25.0.asc → Depth____000025.asc
# Renombrado: Depth____250.0.asc → Depth____000250.asc
# Renombrado: Depth____251.0.asc → Depth____000251.asc
# Renombrado: Depth____252.0.asc → Depth____000252.asc
# Renombrado: Depth____253.0.asc → Depth____000253.asc
# Renombrado: Depth____254.0.asc → Depth____000254.asc
# Renombrado: Depth____255.0.asc → Depth____000255.asc
# Renombrado: Depth____256.0.asc → Depth____000256.asc
# Renombrado: Depth____257.0.asc → Depth____000257.asc
# Renombrado: Depth____258.0.asc → Depth____000258.asc
# Renombrado: Depth____259.0.asc → Depth____000259.asc
# Renombrado: Depth____26.0.asc → Depth____000026.asc
# Renombrado: Depth____260.0.asc → Depth____000260.asc
# Renombrado: Depth____261.0.asc → Depth____000261.asc
# Renombrado: Depth____262.0.asc → Depth____000262.asc
# Renombrado: Depth____263.0.asc → Depth____000263.asc
# Renombrado: Depth____264.0.asc → Depth____000264.asc
# Renombrado: Depth____265.0.asc → Depth____000265.asc
# Renombrado: Depth____266.0.asc → Depth____000266.asc
# Renombrado: Depth____267.0.asc → Depth____000267.asc
# Renombrado: Depth____268.0.asc → Depth____000268.asc
# Renombrado: Depth____269.0.asc → Depth____000269.asc
# Renombrado: Depth____27.0.asc → Depth____000027.asc
# Renombrado: Depth____270.0.asc → Depth____000270.asc
# Renombrado: Depth____271.0.asc → Depth____000271.asc
# Renombrado: Depth____272.0.asc → Depth____000272.asc
# Renombrado: Depth____273.0.asc → Depth____000273.asc
# Renombrado: Depth____274.0.asc → Depth____000274.asc
# Renombrado: Depth____275.0.asc → Depth____000275.asc
# Renombrado: Depth____276.0.asc → Depth____000276.asc
# Renombrado: Depth____277.0.asc → Depth____000277.asc
# Renombrado: Depth____278.0.asc → Depth____000278.asc
# Renombrado: Depth____279.0.asc → Depth____000279.asc
# Renombrado: Depth____28.0.asc → Depth____000028.asc
# Renombrado: Depth____280.0.asc → Depth____000280.asc
# Renombrado: Depth____281.0.asc → Depth____000281.asc
# Renombrado: Depth____282.0.asc → Depth____000282.asc
# Renombrado: Depth____283.0.asc → Depth____000283.asc
# Renombrado: Depth____284.0.asc → Depth____000284.asc
# Renombrado: Depth____285.0.asc → Depth____000285.asc
# Renombrado: Depth____286.0.asc → Depth____000286.asc
# Renombrado: Depth____287.0.asc → Depth____000287.asc
# Renombrado: Depth____288.0.asc → Depth____000288.asc
# Renombrado: Depth____289.0.asc → Depth____000289.asc
# Renombrado: Depth____29.0.asc → Depth____000029.asc
# Renombrado: Depth____290.0.asc → Depth____000290.asc
# Renombrado: Depth____291.0.asc → Depth____000291.asc
# Renombrado: Depth____292.0.asc → Depth____000292.asc
# Renombrado: Depth____293.0.asc → Depth____000293.asc
# Renombrado: Depth____294.0.asc → Depth____000294.asc
# Renombrado: Depth____295.0.asc → Depth____000295.asc
# Renombrado: Depth____296.0.asc → Depth____000296.asc
# Renombrado: Depth____297.0.asc → Depth____000297.asc
# Renombrado: Depth____298.0.asc → Depth____000298.asc
# Renombrado: Depth____299.0.asc → Depth____000299.asc
# Renombrado: Depth____3.0.asc → Depth____000003.asc
# Renombrado: Depth____30.0.asc → Depth____000030.asc
# Renombrado: Depth____300.0.asc → Depth____000300.asc
# Renombrado: Depth____301.0.asc → Depth____000301.asc
# Renombrado: Depth____302.0.asc → Depth____000302.asc
# Renombrado: Depth____303.0.asc → Depth____000303.asc
# Renombrado: Depth____304.0.asc → Depth____000304.asc
# Renombrado: Depth____305.0.asc → Depth____000305.asc
# Renombrado: Depth____306.0.asc → Depth____000306.asc
# Renombrado: Depth____307.0.asc → Depth____000307.asc
# Renombrado: Depth____308.0.asc → Depth____000308.asc
# Renombrado: Depth____309.0.asc → Depth____000309.asc
# Renombrado: Depth____31.0.asc → Depth____000031.asc
# Renombrado: Depth____310.0.asc → Depth____000310.asc
# Renombrado: Depth____311.0.asc → Depth____000311.asc
# Renombrado: Depth____312.0.asc → Depth____000312.asc
# Renombrado: Depth____313.0.asc → Depth____000313.asc
# Renombrado: Depth____314.0.asc → Depth____000314.asc
# Renombrado: Depth____315.0.asc → Depth____000315.asc
# Renombrado: Depth____316.0.asc → Depth____000316.asc
# Renombrado: Depth____317.0.asc → Depth____000317.asc
# Renombrado: Depth____318.0.asc → Depth____000318.asc
# Renombrado: Depth____319.0.asc → Depth____000319.asc
# Renombrado: Depth____32.0.asc → Depth____000032.asc
# Renombrado: Depth____320.0.asc → Depth____000320.asc
# Renombrado: Depth____321.0.asc → Depth____000321.asc
# Renombrado: Depth____322.0.asc → Depth____000322.asc
# Renombrado: Depth____323.0.asc → Depth____000323.asc
# Renombrado: Depth____324.0.asc → Depth____000324.asc
# Renombrado: Depth____325.0.asc → Depth____000325.asc
# Renombrado: Depth____326.0.asc → Depth____000326.asc
# Renombrado: Depth____327.0.asc → Depth____000327.asc
# Renombrado: Depth____328.0.asc → Depth____000328.asc
# Renombrado: Depth____329.0.asc → Depth____000329.asc
# Renombrado: Depth____33.0.asc → Depth____000033.asc
# Renombrado: Depth____330.0.asc → Depth____000330.asc
# Renombrado: Depth____331.0.asc → Depth____000331.asc
# Renombrado: Depth____332.0.asc → Depth____000332.asc
# Renombrado: Depth____333.0.asc → Depth____000333.asc
# Renombrado: Depth____334.0.asc → Depth____000334.asc
# Renombrado: Depth____335.0.asc → Depth____000335.asc
# Renombrado: Depth____336.0.asc → Depth____000336.asc
# Renombrado: Depth____337.0.asc → Depth____000337.asc
# Renombrado: Depth____338.0.asc → Depth____000338.asc
# Renombrado: Depth____339.0.asc → Depth____000339.asc
# Renombrado: Depth____34.0.asc → Depth____000034.asc
# Renombrado: Depth____340.0.asc → Depth____000340.asc
# Renombrado: Depth____341.0.asc → Depth____000341.asc
# Renombrado: Depth____342.0.asc → Depth____000342.asc
# Renombrado: Depth____343.0.asc → Depth____000343.asc
# Renombrado: Depth____344.0.asc → Depth____000344.asc
# Renombrado: Depth____345.0.asc → Depth____000345.asc
# Renombrado: Depth____346.0.asc → Depth____000346.asc
# Renombrado: Depth____347.0.asc → Depth____000347.asc
# Renombrado: Depth____348.0.asc → Depth____000348.asc
# Renombrado: Depth____349.0.asc → Depth____000349.asc
# Renombrado: Depth____35.0.asc → Depth____000035.asc
# Renombrado: Depth____350.0.asc → Depth____000350.asc
# Renombrado: Depth____36.0.asc → Depth____000036.asc
# Renombrado: Depth____37.0.asc → Depth____000037.asc
# Renombrado: Depth____38.0.asc → Depth____000038.asc
# Renombrado: Depth____39.0.asc → Depth____000039.asc
# Renombrado: Depth____4.0.asc → Depth____000004.asc
# Renombrado: Depth____40.0.asc → Depth____000040.asc
# Renombrado: Depth____41.0.asc → Depth____000041.asc
# Renombrado: Depth____42.0.asc → Depth____000042.asc
# Renombrado: Depth____43.0.asc → Depth____000043.asc
# Renombrado: Depth____44.0.asc → Depth____000044.asc
# Renombrado: Depth____45.0.asc → Depth____000045.asc
# Renombrado: Depth____46.0.asc → Depth____000046.asc
# Renombrado: Depth____47.0.asc → Depth____000047.asc
# Renombrado: Depth____48.0.asc → Depth____000048.asc
# Renombrado: Depth____49.0.asc → Depth____000049.asc
# Renombrado: Depth____5.0.asc → Depth____000005.asc
# Renombrado: Depth____50.0.asc → Depth____000050.asc
# Renombrado: Depth____51.0.asc → Depth____000051.asc
# Renombrado: Depth____52.0.asc → Depth____000052.asc
# Renombrado: Depth____53.0.asc → Depth____000053.asc
# Renombrado: Depth____54.0.asc → Depth____000054.asc
# Renombrado: Depth____55.0.asc → Depth____000055.asc
# Renombrado: Depth____56.0.asc → Depth____000056.asc
# Renombrado: Depth____57.0.asc → Depth____000057.asc
# Renombrado: Depth____58.0.asc → Depth____000058.asc
# Renombrado: Depth____59.0.asc → Depth____000059.asc
# Renombrado: Depth____6.0.asc → Depth____000006.asc
# Renombrado: Depth____60.0.asc → Depth____000060.asc
# Renombrado: Depth____61.0.asc → Depth____000061.asc
# Renombrado: Depth____62.0.asc → Depth____000062.asc
# Renombrado: Depth____63.0.asc → Depth____000063.asc
# Renombrado: Depth____64.0.asc → Depth____000064.asc
# Renombrado: Depth____65.0.asc → Depth____000065.asc
# Renombrado: Depth____66.0.asc → Depth____000066.asc
# Renombrado: Depth____67.0.asc → Depth____000067.asc
# Renombrado: Depth____68.0.asc → Depth____000068.asc
# Renombrado: Depth____69.0.asc → Depth____000069.asc
# Renombrado: Depth____7.0.asc → Depth____000007.asc
# Renombrado: Depth____70.0.asc → Depth____000070.asc
# Renombrado: Depth____71.0.asc → Depth____000071.asc
# Renombrado: Depth____72.0.asc → Depth____000072.asc
# Renombrado: Depth____73.0.asc → Depth____000073.asc
# Renombrado: Depth____74.0.asc → Depth____000074.asc
# Renombrado: Depth____75.0.asc → Depth____000075.asc
# Renombrado: Depth____76.0.asc → Depth____000076.asc
# Renombrado: Depth____77.0.asc → Depth____000077.asc
# Renombrado: Depth____78.0.asc → Depth____000078.asc
# Renombrado: Depth____79.0.asc → Depth____000079.asc
# Renombrado: Depth____8.0.asc → Depth____000008.asc
# Renombrado: Depth____80.0.asc → Depth____000080.asc
# Renombrado: Depth____81.0.asc → Depth____000081.asc
# Renombrado: Depth____82.0.asc → Depth____000082.asc
# Renombrado: Depth____83.0.asc → Depth____000083.asc
# Renombrado: Depth____84.0.asc → Depth____000084.asc
# Renombrado: Depth____85.0.asc → Depth____000085.asc
# Renombrado: Depth____86.0.asc → Depth____000086.asc
# Renombrado: Depth____87.0.asc → Depth____000087.asc
# Renombrado: Depth____88.0.asc → Depth____000088.asc
# Renombrado: Depth____89.0.asc → Depth____000089.asc
# Renombrado: Depth____9.0.asc → Depth____000009.asc
# Renombrado: Depth____90.0.asc → Depth____000090.asc
# Renombrado: Depth____91.0.asc → Depth____000091.asc
# Renombrado: Depth____92.0.asc → Depth____000092.asc
# Renombrado: Depth____93.0.asc → Depth____000093.asc
# Renombrado: Depth____94.0.asc → Depth____000094.asc
# Renombrado: Depth____95.0.asc → Depth____000095.asc
# Renombrado: Depth____96.0.asc → Depth____000096.asc
# Renombrado: Depth____97.0.asc → Depth____000097.asc
# Renombrado: Depth____98.0.asc → Depth____000098.asc
# Renombrado: Depth____99.0.asc → Depth____000099.asc
#
# Todos los archivos han sido renombrados correctamente.

# %%
import os
import re
import numpy as np
import rasterio
from rasterio.transform import from_origin
from rasterio.io import MemoryFile
from rasterio.warp import calculate_default_transform, reproject, Resampling
from pyproj import Transformer
from PIL import Image, ImageDraw, ImageFont

# ====================================================
# PARÁMETROS GLOBALES
# ====================================================

INPUT_DIR = r"C:\temp\cruce_test.gid\Rasters\Hydraulic"  # Carpeta donde están los archivos ASC
OUTPUT_DIR = r"C:\temp\cruce_test.gid\Rasters\Hydraulic\Processed"  # Carpeta donde se guardarán los PNGs y TIFs
USER_MAX_DEPTH = 2.0  # Valor máximo de profundidad en metros
SRC_CRS = "EPSG:2056"  # CRS de origen (CH1903+ / LV95)
DST_CRS = "EPSG:3857"  # CRS de salida (Web Mercator)

# Crear la carpeta de salida si no existe
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# ====================================================
# FUNCIÓN PARA LEER ARCHIVOS ASC
# ====================================================

def read_ascii_xllcenter(filename):
    """Lee un archivo ASC y extrae sus datos y metadatos."""
    with open(filename, 'r') as f:
        header_lines = [next(f) for _ in range(6)]
    
    ncols = nrows = None
    xllcenter = yllcenter = None
    cellsize = None
    nodata_val = None

    for line in header_lines:
        parts = re.split(r"\s+", line.strip())
        key = parts[0].upper()
        val = float(parts[-1])
        if key.startswith("NCOLS"):
            ncols = int(val)
        elif key.startswith("NROWS"):
            nrows = int(val)
        elif key.startswith("XLLCENTER"):
            xllcenter = val
        elif key.startswith("YLLCENTER"):
            yllcenter = val
        elif key.startswith("CELLSIZE"):
            cellsize = val
        elif key.startswith("NODATA_VALUE"):
            nodata_val = val

    data = np.loadtxt(filename, skiprows=6)
    x_min = xllcenter - 0.5 * cellsize
    y_max = yllcenter + (nrows - 0.5) * cellsize
    transform = from_origin(x_min, y_max, cellsize, cellsize)
    return data, transform, ncols, nrows, nodata_val

# ====================================================
# FUNCIÓN PARA CONVERTIR ASC A PNG
# ====================================================

def asc_to_png(filename_asc, output_png):
    """Convierte un archivo ASC en una imagen PNG con una rampa de colores."""
    data, transform, width, height, nodata_val = read_ascii_xllcenter(filename_asc)
    
    low_rgb = np.array([173, 216, 230], dtype=np.float32)  # Azul claro
    high_rgb = np.array([0, 0, 139], dtype=np.float32)      # Azul oscuro
    limit_val = 0.9 * USER_MAX_DEPTH

    band = data
    valid_mask = band != nodata_val
    scaled = ((band - 0) / (limit_val - 0)) * 255.0
    scaled = np.clip(scaled, 0, 255).astype(np.float32)

    R = low_rgb[0] + (high_rgb[0] - low_rgb[0]) * (scaled / 255.0)
    G = low_rgb[1] + (high_rgb[1] - low_rgb[1]) * (scaled / 255.0)
    B = low_rgb[2] + (high_rgb[2] - low_rgb[2]) * (scaled / 255.0)

    R = np.clip(R, 0, 255).astype(np.uint8)
    G = np.clip(G, 0, 255).astype(np.uint8)
    B = np.clip(B, 0, 255).astype(np.uint8)
    A = np.where(valid_mask, 255, 0).astype(np.uint8)

    img = np.dstack([R, G, B, A])
    Image.fromarray(img).save(output_png)

# ====================================================
# FUNCIÓN PARA RENOMBRAR LOS ARCHIVOS ASC
# ====================================================

def format_filename(filename):
    """Renombra archivos ASC a PNG con 6 cifras en el nombre."""
    match = re.search(r"Depth____(\d+)\.asc", filename)
    if match:
        num = int(match.group(1))
        formatted_num = f"{num:06d}"
        return f"Depth_{formatted_num}.png"
    return None

def extract_number(filename):
    """Extrae el número de tiempo de los archivos ASC."""
    match = re.search(r"Depth____(\d+)\.asc", filename)
    return int(match.group(1)) if match else float('inf')

# ====================================================
# PROCESAMIENTO DE ARCHIVOS
# ====================================================

# Listar archivos ASC y ordenarlos por tiempo
asc_files = [f for f in os.listdir(INPUT_DIR) if f.startswith("Depth____") and f.endswith(".asc")]
asc_files = sorted(asc_files, key=extract_number)

print(f"Se encontraron {len(asc_files)} archivos ASC para procesar.")

for filename in asc_files:
    input_path = os.path.join(INPUT_DIR, filename)
    output_name = format_filename(filename)  # Ejemplo: Depth_000123.png

    if output_name is not None:
        output_path = os.path.join(OUTPUT_DIR, output_name)
        asc_to_png(input_path, output_path)
        print(f"{filename} → {output_name}")

print("\nProceso completado. Archivos PNG generados en:", OUTPUT_DIR)
# Out:
# Se encontraron 351 archivos ASC para procesar.
# Depth____000000.asc → Depth_000000.png
# Depth____000001.asc → Depth_000001.png
# Depth____000002.asc → Depth_000002.png
# Depth____000003.asc → Depth_000003.png
# Depth____000004.asc → Depth_000004.png
# Depth____000005.asc → Depth_000005.png
# Depth____000006.asc → Depth_000006.png
# Depth____000007.asc → Depth_000007.png
# Depth____000008.asc → Depth_000008.png
# Depth____000009.asc → Depth_000009.png
# Depth____000010.asc → Depth_000010.png
# Depth____000011.asc → Depth_000011.png
# Depth____000012.asc → Depth_000012.png
# Depth____000013.asc → Depth_000013.png
# Depth____000014.asc → Depth_000014.png
# Depth____000015.asc → Depth_000015.png
# Depth____000016.asc → Depth_000016.png
# Depth____000017.asc → Depth_000017.png
# Depth____000018.asc → Depth_000018.png
# Depth____000019.asc → Depth_000019.png
# Depth____000020.asc → Depth_000020.png
# Depth____000021.asc → Depth_000021.png
# Depth____000022.asc → Depth_000022.png
# Depth____000023.asc → Depth_000023.png
# Depth____000024.asc → Depth_000024.png
# Depth____000025.asc → Depth_000025.png
# Depth____000026.asc → Depth_000026.png
# Depth____000027.asc → Depth_000027.png
# Depth____000028.asc → Depth_000028.png
# Depth____000029.asc → Depth_000029.png
# Depth____000030.asc → Depth_000030.png
# Depth____000031.asc → Depth_000031.png
# Depth____000032.asc → Depth_000032.png
# Depth____000033.asc → Depth_000033.png
# Depth____000034.asc → Depth_000034.png
# Depth____000035.asc → Depth_000035.png
# Depth____000036.asc → Depth_000036.png
# Depth____000037.asc → Depth_000037.png
# Depth____000038.asc → Depth_000038.png
# Depth____000039.asc → Depth_000039.png
# Depth____000040.asc → Depth_000040.png
# Depth____000041.asc → Depth_000041.png
# Depth____000042.asc → Depth_000042.png
# Depth____000043.asc → Depth_000043.png
# Depth____000044.asc → Depth_000044.png
# Depth____000045.asc → Depth_000045.png
# Depth____000046.asc → Depth_000046.png
# Depth____000047.asc → Depth_000047.png
# Depth____000048.asc → Depth_000048.png
# Depth____000049.asc → Depth_000049.png
# Depth____000050.asc → Depth_000050.png
# Depth____000051.asc → Depth_000051.png
# Depth____000052.asc → Depth_000052.png
# Depth____000053.asc → Depth_000053.png
# Depth____000054.asc → Depth_000054.png
# Depth____000055.asc → Depth_000055.png
# Depth____000056.asc → Depth_000056.png
# Depth____000057.asc → Depth_000057.png
# Depth____000058.asc → Depth_000058.png
# Depth____000059.asc → Depth_000059.png
# Depth____000060.asc → Depth_000060.png
# Depth____000061.asc → Depth_000061.png
# Depth____000062.asc → Depth_000062.png
# Depth____000063.asc → Depth_000063.png
# Depth____000064.asc → Depth_000064.png
# Depth____000065.asc → Depth_000065.png
# Depth____000066.asc → Depth_000066.png
# Depth____000067.asc → Depth_000067.png
# Depth____000068.asc → Depth_000068.png
# Depth____000069.asc → Depth_000069.png
# Depth____000070.asc → Depth_000070.png
# Depth____000071.asc → Depth_000071.png
# Depth____000072.asc → Depth_000072.png
# Depth____000073.asc → Depth_000073.png
# Depth____000074.asc → Depth_000074.png
# Depth____000075.asc → Depth_000075.png
# Depth____000076.asc → Depth_000076.png
# Depth____000077.asc → Depth_000077.png
# Depth____000078.asc → Depth_000078.png
# Depth____000079.asc → Depth_000079.png
# Depth____000080.asc → Depth_000080.png
# Depth____000081.asc → Depth_000081.png
# Depth____000082.asc → Depth_000082.png
# Depth____000083.asc → Depth_000083.png
# Depth____000084.asc → Depth_000084.png
# Depth____000085.asc → Depth_000085.png
# Depth____000086.asc → Depth_000086.png
# Depth____000087.asc → Depth_000087.png
# Depth____000088.asc → Depth_000088.png
# Depth____000089.asc → Depth_000089.png
# Depth____000090.asc → Depth_000090.png
# Depth____000091.asc → Depth_000091.png
# Depth____000092.asc → Depth_000092.png
# Depth____000093.asc → Depth_000093.png
# Depth____000094.asc → Depth_000094.png
# Depth____000095.asc → Depth_000095.png
# Depth____000096.asc → Depth_000096.png
# Depth____000097.asc → Depth_000097.png
# Depth____000098.asc → Depth_000098.png
# Depth____000099.asc → Depth_000099.png
# Depth____000100.asc → Depth_000100.png
# Depth____000101.asc → Depth_000101.png
# Depth____000102.asc → Depth_000102.png
# Depth____000103.asc → Depth_000103.png
# Depth____000104.asc → Depth_000104.png
# Depth____000105.asc → Depth_000105.png
# Depth____000106.asc → Depth_000106.png
# Depth____000107.asc → Depth_000107.png
# Depth____000108.asc → Depth_000108.png
# Depth____000109.asc → Depth_000109.png
# Depth____000110.asc → Depth_000110.png
# Depth____000111.asc → Depth_000111.png
# Depth____000112.asc → Depth_000112.png
# Depth____000113.asc → Depth_000113.png
# Depth____000114.asc → Depth_000114.png
# Depth____000115.asc → Depth_000115.png
# Depth____000116.asc → Depth_000116.png
# Depth____000117.asc → Depth_000117.png
# Depth____000118.asc → Depth_000118.png
# Depth____000119.asc → Depth_000119.png
# Depth____000120.asc → Depth_000120.png
# Depth____000121.asc → Depth_000121.png
# Depth____000122.asc → Depth_000122.png
# Depth____000123.asc → Depth_000123.png
# Depth____000124.asc → Depth_000124.png
# Depth____000125.asc → Depth_000125.png
# Depth____000126.asc → Depth_000126.png
# Depth____000127.asc → Depth_000127.png
# Depth____000128.asc → Depth_000128.png
# Depth____000129.asc → Depth_000129.png
# Depth____000130.asc → Depth_000130.png
# Depth____000131.asc → Depth_000131.png
# Depth____000132.asc → Depth_000132.png
# Depth____000133.asc → Depth_000133.png
# Depth____000134.asc → Depth_000134.png
# Depth____000135.asc → Depth_000135.png
# Depth____000136.asc → Depth_000136.png
# Depth____000137.asc → Depth_000137.png
# Depth____000138.asc → Depth_000138.png
# Depth____000139.asc → Depth_000139.png
# Depth____000140.asc → Depth_000140.png
# Depth____000141.asc → Depth_000141.png
# Depth____000142.asc → Depth_000142.png
# Depth____000143.asc → Depth_000143.png
# Depth____000144.asc → Depth_000144.png
# Depth____000145.asc → Depth_000145.png
# Depth____000146.asc → Depth_000146.png
# Depth____000147.asc → Depth_000147.png
# Depth____000148.asc → Depth_000148.png
# Depth____000149.asc → Depth_000149.png
# Depth____000150.asc → Depth_000150.png
# Depth____000151.asc → Depth_000151.png
# Depth____000152.asc → Depth_000152.png
# Depth____000153.asc → Depth_000153.png
# Depth____000154.asc → Depth_000154.png
# Depth____000155.asc → Depth_000155.png
# Depth____000156.asc → Depth_000156.png
# Depth____000157.asc → Depth_000157.png
# Depth____000158.asc → Depth_000158.png
# Depth____000159.asc → Depth_000159.png
# Depth____000160.asc → Depth_000160.png
# Depth____000161.asc → Depth_000161.png
# Depth____000162.asc → Depth_000162.png
# Depth____000163.asc → Depth_000163.png
# Depth____000164.asc → Depth_000164.png
# Depth____000165.asc → Depth_000165.png
# Depth____000166.asc → Depth_000166.png
# Depth____000167.asc → Depth_000167.png
# Depth____000168.asc → Depth_000168.png
# Depth____000169.asc → Depth_000169.png
# Depth____000170.asc → Depth_000170.png
# Depth____000171.asc → Depth_000171.png
# Depth____000172.asc → Depth_000172.png
# Depth____000173.asc → Depth_000173.png
# Depth____000174.asc → Depth_000174.png
# Depth____000175.asc → Depth_000175.png
# Depth____000176.asc → Depth_000176.png
# Depth____000177.asc → Depth_000177.png
# Depth____000178.asc → Depth_000178.png
# Depth____000179.asc → Depth_000179.png
# Depth____000180.asc → Depth_000180.png
# Depth____000181.asc → Depth_000181.png
# Depth____000182.asc → Depth_000182.png
# Depth____000183.asc → Depth_000183.png
# Depth____000184.asc → Depth_000184.png
# Depth____000185.asc → Depth_000185.png
# Depth____000186.asc → Depth_000186.png
# Depth____000187.asc → Depth_000187.png
# Depth____000188.asc → Depth_000188.png
# Depth____000189.asc → Depth_000189.png
# Depth____000190.asc → Depth_000190.png
# Depth____000191.asc → Depth_000191.png
# Depth____000192.asc → Depth_000192.png
# Depth____000193.asc → Depth_000193.png
# Depth____000194.asc → Depth_000194.png
# Depth____000195.asc → Depth_000195.png
# Depth____000196.asc → Depth_000196.png
# Depth____000197.asc → Depth_000197.png
# Depth____000198.asc → Depth_000198.png
# Depth____000199.asc → Depth_000199.png
# Depth____000200.asc → Depth_000200.png
# Depth____000201.asc → Depth_000201.png
# Depth____000202.asc → Depth_000202.png
# Depth____000203.asc → Depth_000203.png
# Depth____000204.asc → Depth_000204.png
# Depth____000205.asc → Depth_000205.png
# Depth____000206.asc → Depth_000206.png
# Depth____000207.asc → Depth_000207.png
# Depth____000208.asc → Depth_000208.png
# Depth____000209.asc → Depth_000209.png
# Depth____000210.asc → Depth_000210.png
# Depth____000211.asc → Depth_000211.png
# Depth____000212.asc → Depth_000212.png
# Depth____000213.asc → Depth_000213.png
# Depth____000214.asc → Depth_000214.png
# Depth____000215.asc → Depth_000215.png
# Depth____000216.asc → Depth_000216.png
# Depth____000217.asc → Depth_000217.png
# Depth____000218.asc → Depth_000218.png
# Depth____000219.asc → Depth_000219.png
# Depth____000220.asc → Depth_000220.png
# Depth____000221.asc → Depth_000221.png
# Depth____000222.asc → Depth_000222.png
# Depth____000223.asc → Depth_000223.png
# Depth____000224.asc → Depth_000224.png
# Depth____000225.asc → Depth_000225.png
# Depth____000226.asc → Depth_000226.png
# Depth____000227.asc → Depth_000227.png
# Depth____000228.asc → Depth_000228.png
# Depth____000229.asc → Depth_000229.png
# Depth____000230.asc → Depth_000230.png
# Depth____000231.asc → Depth_000231.png
# Depth____000232.asc → Depth_000232.png
# Depth____000233.asc → Depth_000233.png
# Depth____000234.asc → Depth_000234.png
# Depth____000235.asc → Depth_000235.png
# Depth____000236.asc → Depth_000236.png
# Depth____000237.asc → Depth_000237.png
# Depth____000238.asc → Depth_000238.png
# Depth____000239.asc → Depth_000239.png
# Depth____000240.asc → Depth_000240.png
# Depth____000241.asc → Depth_000241.png
# Depth____000242.asc → Depth_000242.png
# Depth____000243.asc → Depth_000243.png
# Depth____000244.asc → Depth_000244.png
# Depth____000245.asc → Depth_000245.png
# Depth____000246.asc → Depth_000246.png
# Depth____000247.asc → Depth_000247.png
# Depth____000248.asc → Depth_000248.png
# Depth____000249.asc → Depth_000249.png
# Depth____000250.asc → Depth_000250.png
# Depth____000251.asc → Depth_000251.png
# Depth____000252.asc → Depth_000252.png
# Depth____000253.asc → Depth_000253.png
# Depth____000254.asc → Depth_000254.png
# Depth____000255.asc → Depth_000255.png
# Depth____000256.asc → Depth_000256.png
# Depth____000257.asc → Depth_000257.png
# Depth____000258.asc → Depth_000258.png
# Depth____000259.asc → Depth_000259.png
# Depth____000260.asc → Depth_000260.png
# Depth____000261.asc → Depth_000261.png
# Depth____000262.asc → Depth_000262.png
# Depth____000263.asc → Depth_000263.png
# Depth____000264.asc → Depth_000264.png
# Depth____000265.asc → Depth_000265.png
# Depth____000266.asc → Depth_000266.png
# Depth____000267.asc → Depth_000267.png
# Depth____000268.asc → Depth_000268.png
# Depth____000269.asc → Depth_000269.png
# Depth____000270.asc → Depth_000270.png
# Depth____000271.asc → Depth_000271.png
# Depth____000272.asc → Depth_000272.png
# Depth____000273.asc → Depth_000273.png
# Depth____000274.asc → Depth_000274.png
# Depth____000275.asc → Depth_000275.png
# Depth____000276.asc → Depth_000276.png
# Depth____000277.asc → Depth_000277.png
# Depth____000278.asc → Depth_000278.png
# Depth____000279.asc → Depth_000279.png
# Depth____000280.asc → Depth_000280.png
# Depth____000281.asc → Depth_000281.png
# Depth____000282.asc → Depth_000282.png
# Depth____000283.asc → Depth_000283.png
# Depth____000284.asc → Depth_000284.png
# Depth____000285.asc → Depth_000285.png
# Depth____000286.asc → Depth_000286.png
# Depth____000287.asc → Depth_000287.png
# Depth____000288.asc → Depth_000288.png
# Depth____000289.asc → Depth_000289.png
# Depth____000290.asc → Depth_000290.png
# Depth____000291.asc → Depth_000291.png
# Depth____000292.asc → Depth_000292.png
# Depth____000293.asc → Depth_000293.png
# Depth____000294.asc → Depth_000294.png
# Depth____000295.asc → Depth_000295.png
# Depth____000296.asc → Depth_000296.png
# Depth____000297.asc → Depth_000297.png
# Depth____000298.asc → Depth_000298.png
# Depth____000299.asc → Depth_000299.png
# Depth____000300.asc → Depth_000300.png
# Depth____000301.asc → Depth_000301.png
# Depth____000302.asc → Depth_000302.png
# Depth____000303.asc → Depth_000303.png
# Depth____000304.asc → Depth_000304.png
# Depth____000305.asc → Depth_000305.png
# Depth____000306.asc → Depth_000306.png
# Depth____000307.asc → Depth_000307.png
# Depth____000308.asc → Depth_000308.png
# Depth____000309.asc → Depth_000309.png
# Depth____000310.asc → Depth_000310.png
# Depth____000311.asc → Depth_000311.png
# Depth____000312.asc → Depth_000312.png
# Depth____000313.asc → Depth_000313.png
# Depth____000314.asc → Depth_000314.png
# Depth____000315.asc → Depth_000315.png
# Depth____000316.asc → Depth_000316.png
# Depth____000317.asc → Depth_000317.png
# Depth____000318.asc → Depth_000318.png
# Depth____000319.asc → Depth_000319.png
# Depth____000320.asc → Depth_000320.png
# Depth____000321.asc → Depth_000321.png
# Depth____000322.asc → Depth_000322.png
# Depth____000323.asc → Depth_000323.png
# Depth____000324.asc → Depth_000324.png
# Depth____000325.asc → Depth_000325.png
# Depth____000326.asc → Depth_000326.png
# Depth____000327.asc → Depth_000327.png
# Depth____000328.asc → Depth_000328.png
# Depth____000329.asc → Depth_000329.png
# Depth____000330.asc → Depth_000330.png
# Depth____000331.asc → Depth_000331.png
# Depth____000332.asc → Depth_000332.png
# Depth____000333.asc → Depth_000333.png
# Depth____000334.asc → Depth_000334.png
# Depth____000335.asc → Depth_000335.png
# Depth____000336.asc → Depth_000336.png
# Depth____000337.asc → Depth_000337.png
# Depth____000338.asc → Depth_000338.png
# Depth____000339.asc → Depth_000339.png
# Depth____000340.asc → Depth_000340.png
# Depth____000341.asc → Depth_000341.png
# Depth____000342.asc → Depth_000342.png
# Depth____000343.asc → Depth_000343.png
# Depth____000344.asc → Depth_000344.png
# Depth____000345.asc → Depth_000345.png
# Depth____000346.asc → Depth_000346.png
# Depth____000347.asc → Depth_000347.png
# Depth____000348.asc → Depth_000348.png
# Depth____000349.asc → Depth_000349.png
# Depth____000350.asc → Depth_000350.png
#
# Proceso completado. Archivos PNG generados en: C:\temp\cruce_test.gid\Rasters\Hydraulic\Processed

# %% [markdown]
# Si no está instalado Git:

# %% [markdown]
# ```raw
# !conda install -c conda-forge git -y
#
#
# !git --version
#
#
# !git config --global user.name "cgotelli"
# !git config --global user.email "clemente.gotelli@outlook.com"
#
#
# !git config --global --list
# ```

# %% [markdown]
# Una vez listo eso, clonamos:

# %% [markdown]
# ```raw
# !git clone https://github.com/cgotelli/Floods-WebMap.git G:/Floods-WebMap
# ```

# %%
import shutil
import os
import numpy as np
from PIL import Image, ImageDraw, ImageFont

# Directorios en el disco G:
local_repo_dir = r"G:\Floods-WebMap"  # Directorio del repo clonado en G:
source_images_dir = r"C:\temp\cruce_test.gid\Rasters\Hydraulic\Processed"  # PNGs generados
source_asc_dir = r"C:\temp\cruce_test.gid\Rasters\Hydraulic"  # Archivos ASC generados

# Directorios de destino en el repositorio en G:
target_png_dir = os.path.join(local_repo_dir, "simulation_files", "png")
target_asc_dir = os.path.join(local_repo_dir, "simulation_files", "asc")
target_aux_dir = os.path.join(local_repo_dir, "aux_images")  # Carpeta para la leyenda

# Parámetros de la leyenda
LEGEND_WIDTH = 50
LEGEND_HEIGHT = 256
TOP_MARGIN = 40
BOTTOM_MARGIN = 20
LEFT_MARGIN = 25
RIGHT_MARGIN = 10
USER_MAX_DEPTH = 2.0  # Máxima profundidad a considerar en la leyenda

# Función para limpiar carpetas antes de copiar nuevos archivos (excepto aux_images)
def clean_directory(directory):
    if os.path.exists(directory):
        for file in os.listdir(directory):
            file_path = os.path.join(directory, file)
            try:
                os.remove(file_path)
                print(f"🗑️ Eliminado: {file}")
            except Exception as e:
                print(f"⚠️ Error al eliminar {file}: {e}")
    else:
        os.makedirs(directory)

# Limpiar carpetas PNG y ASC antes de copiar nuevos archivos (NO TOCAR aux_images)
print("🧹 Eliminando archivos anteriores en G:/Floods-WebMap/simulation_files/png...")
clean_directory(target_png_dir)

print("🧹 Eliminando archivos anteriores en G:/Floods-WebMap/simulation_files/asc...")
clean_directory(target_asc_dir)

# Función para copiar archivos
def copy_files(source_dir, target_dir, extension):
    for file in os.listdir(source_dir):
        if file.endswith(extension):
            shutil.copy2(os.path.join(source_dir, file), os.path.join(target_dir, file))
            print(f"📂 Copiado: {file}")

# Copiar nuevos archivos PNG
print("\n📤 Copiando nuevos archivos PNG...")
copy_files(source_images_dir, target_png_dir, ".png")

# Copiar nuevos archivos ASC
print("\n📤 Copiando nuevos archivos ASC...")
copy_files(source_asc_dir, target_asc_dir, ".asc")

# ====================================================
# Generar la imagen de la leyenda (SIN ELIMINAR ARCHIVOS ANTERIORES EN aux_images)
# ====================================================

print("\n🎨 Generando la leyenda...")

# Crear imagen RGBA para la leyenda
legend_array = np.ones((LEGEND_HEIGHT, LEGEND_WIDTH, 4), dtype=np.uint8) * 255
legend_array[..., 3] = 128  # Fondo con 50% de opacidad

# Gradiente de color (azul claro a azul oscuro)
low_rgb = np.array([173, 216, 230], dtype=np.float32)  # Azul claro
high_rgb = np.array([0, 0, 139], dtype=np.float32)  # Azul oscuro
limit_val = 0.9 * USER_MAX_DEPTH

inner_height = LEGEND_HEIGHT - TOP_MARGIN - BOTTOM_MARGIN
for y in range(inner_height):
    factor = y / float(inner_height - 1)
    inv_factor = 1 - factor  # Invertir para que la parte superior sea azul oscuro
    color = low_rgb + (high_rgb - low_rgb) * inv_factor
    color = np.clip(color, 0, 255).astype(np.uint8)
    for x in range(LEFT_MARGIN, LEGEND_WIDTH - RIGHT_MARGIN):
        legend_array[TOP_MARGIN + y, x, :3] = color
        legend_array[TOP_MARGIN + y, x, 3] = 255  # Opaque en la barra de color

# Convertir a imagen
legend_img = Image.fromarray(legend_array, mode="RGBA")
draw = ImageDraw.Draw(legend_img)
font = ImageFont.load_default()

# Etiquetas
title_text = "Depth [m]"
draw.text(((LEGEND_WIDTH - draw.textlength(title_text, font)) // 2, 2), title_text, font=font, fill=(0, 0, 0, 255))

# Min label (0)
draw.text((LEFT_MARGIN - 10, LEGEND_HEIGHT - BOTTOM_MARGIN), "0", font=font, fill=(0, 0, 0, 255))

# Max label (90% de USER_MAX_DEPTH)
max_label = f"{limit_val:.1f}"
draw.text((LEFT_MARGIN - 10, TOP_MARGIN - 10), max_label, font=font, fill=(0, 0, 0, 255))

# Guardar la leyenda en G:\Floods-WebMap\aux_images (NO SE ELIMINAN ARCHIVOS ANTERIORES)
legend_output = os.path.join(target_aux_dir, "legend.png")
legend_img.save(legend_output)
print(f"✅ Leyenda guardada en {legend_output}")

print("\n✅ Todos los archivos han sido copiados en G:/Floods-WebMap.")
# Out:
# 🧹 Eliminando archivos anteriores en G:/Floods-WebMap/simulation_files/png...
# 🗑️ Eliminado: Depth_000000.png
# 🗑️ Eliminado: Depth_000001.png
# 🗑️ Eliminado: Depth_000002.png
# 🗑️ Eliminado: Depth_000003.png
# 🗑️ Eliminado: Depth_000004.png
# 🗑️ Eliminado: Depth_000005.png
# 🗑️ Eliminado: Depth_000006.png
# 🗑️ Eliminado: Depth_000007.png
# 🗑️ Eliminado: Depth____000336.asc
# 🗑️ Eliminado: Depth____000337.asc
# 🗑️ Eliminado: Depth____000338.asc
# 🗑️ Eliminado: Depth____000339.asc
# 🗑️ Eliminado: Depth____000340.asc
# 🗑️ Eliminado: Depth____000341.asc
# 🗑️ Eliminado: Depth____000342.asc
# 🗑️ Eliminado: Depth____000343.asc
# 🗑️ Eliminado: Depth____000344.asc
# 🗑️ Eliminado: Depth____000345.asc
# 🗑️ Eliminado: Depth____000346.asc
# 🗑️ Eliminado: Depth____000347.asc
# 🗑️ Eliminado: Depth____000348.asc
# 🗑️ Eliminado: Depth____000349.asc
# 🗑️ Eliminado: Depth____000350.asc
# 🗑️ Eliminado: Velocity__x_0.0.asc
# 🗑️ Eliminado: Velocity__x_1.0.asc
# 🗑️ Eliminado: Velocity__x_10.0.asc
# 🗑️ Eliminado: Velocity__x_100.0.asc
# 🗑️ Eliminado: Velocity__x_101.0.asc
# 🗑️ Eliminado: Velocity__x_102.0.asc
# 🗑️ Eliminado: Velocity__x_103.0.asc
# 🗑️ Eliminado: Velocity__x_104.0.asc
# 🗑️ Eliminado: Velocity__x_105.0.asc
# 🗑️ Eliminado: Velocity__x_106.0.asc
# 🗑️ Eliminado: Velocity__x_107.0.asc
# 🗑️ Eliminado: Velocity__x_108.0.asc
# 🗑️ Eliminado: Velocity__x_109.0.asc
# 🗑️ Eliminado: Velocity__x_11.0.asc
# 🗑️ Eliminado: Velocity__x_110.0.asc
# 🗑️ Eliminado: Velocity__x_111.0.asc
# 🗑️ Eliminado: Velocity__x_112.0.asc
# 🗑️ Eliminado: Velocity__x_113.0.asc
# 🗑️ Eliminado: Velocity__x_114.0.asc
# 🗑️ Eliminado: Velocity__x_115.0.asc
# 🗑️ Eliminado: Velocity__x_116.0.asc
# 🗑️ Eliminado: Velocity__x_117.0.asc
# 🗑️ Eliminado: Velocity__x_118.0.asc
# 🗑️ Eliminado: Velocity__x_119.0.asc
# 🗑️ Eliminado: Velocity__x_12.0.asc
# 🗑️ Eliminado: Velocity__x_120.0.asc
# 🗑️ Eliminado: Velocity__x_121.0.asc
# 🗑️ Eliminado: Velocity__x_122.0.asc
# 🗑️ Eliminado: Velocity__x_123.0.asc
# 🗑️ Eliminado: Velocity__x_124.0.asc
# 🗑️ Eliminado: Velocity__x_125.0.asc
# 🗑️ Eliminado: Velocity__x_126.0.asc
# 🗑️ Eliminado: Velocity__x_127.0.asc
# 🗑️ Eliminado: Velocity__x_128.0.asc
# 🗑️ Eliminado: Velocity__x_129.0.asc
# 🗑️ Eliminado: Velocity__x_13.0.asc
# 🗑️ Eliminado: Velocity__x_130.0.asc
# 🗑️ Eliminado: Velocity__x_131.0.asc
# 🗑️ Eliminado: Velocity__x_132.0.asc
# 🗑️ Eliminado: Velocity__x_133.0.asc
# 🗑️ Eliminado: Velocity__x_134.0.asc
# 🗑️ Eliminado: Velocity__x_135.0.asc
# 🗑️ Eliminado: Velocity__x_136.0.asc
# 🗑️ Eliminado: Velocity__x_137.0.asc
# 🗑️ Eliminado: Velocity__x_138.0.asc
# 🗑️ Eliminado: Velocity__x_139.0.asc
# 🗑️ Eliminado: Velocity__x_14.0.asc
# 🗑️ Eliminado: Velocity__x_140.0.asc
# 🗑️ Eliminado: Velocity__x_141.0.asc
# 🗑️ Eliminado: Velocity__x_142.0.asc
# 🗑️ Eliminado: Velocity__x_143.0.asc
# 🗑️ Eliminado: Velocity__x_144.0.asc
# 🗑️ Eliminado: Velocity__x_145.0.asc
# 🗑️ Eliminado: Velocity__x_146.0.asc
# 🗑️ Eliminado: Velocity__x_147.0.asc
# 🗑️ Eliminado: Velocity__x_148.0.asc
# 🗑️ Eliminado: Velocity__x_149.0.asc
# 🗑️ Eliminado: Velocity__x_15.0.asc
# 🗑️ Eliminado: Velocity__x_150.0.asc
# 🗑️ Eliminado: Velocity__x_151.0.asc
# 🗑️ Eliminado: Velocity__x_152.0.asc
# 🗑️ Eliminado: Velocity__x_153.0.asc
# 🗑️ Eliminado: Velocity__x_154.0.asc
# 🗑️ Eliminado: Velocity__x_155.0.asc
# 🗑️ Eliminado: Velocity__x_156.0.asc
# 🗑️ Eliminado: Velocity__x_157.0.asc
# 🗑️ Eliminado: Velocity__x_158.0.asc
# 🗑️ Eliminado: Velocity__x_159.0.asc
# 🗑️ Eliminado: Velocity__x_16.0.asc
# 🗑️ Eliminado: Velocity__x_160.0.asc
# 🗑️ Eliminado: Velocity__x_161.0.asc
# 🗑️ Eliminado: Velocity__x_162.0.asc
# 🗑️ Eliminado: Velocity__x_163.0.asc
# 🗑️ Eliminado: Velocity__x_164.0.asc
# 🗑️ Eliminado: Velocity__x_165.0.asc
# 🗑️ Eliminado: Velocity__x_166.0.asc
# 🗑️ Eliminado: Velocity__x_167.0.asc
# 🗑️ Eliminado: Velocity__x_168.0.asc
# 🗑️ Eliminado: Velocity__x_169.0.asc
# 🗑️ Eliminado: Velocity__x_17.0.asc
# 🗑️ Eliminado: Velocity__x_170.0.asc
# 🗑️ Eliminado: Velocity__x_171.0.asc
# 🗑️ Eliminado: Velocity__x_172.0.asc
# 🗑️ Eliminado: Velocity__x_173.0.asc
# 🗑️ Eliminado: Velocity__x_174.0.asc
# 🗑️ Eliminado: Velocity__x_175.0.asc
# 🗑️ Eliminado: Velocity__x_176.0.asc
# 🗑️ Eliminado: Velocity__x_177.0.asc
# 🗑️ Eliminado: Velocity__x_178.0.asc
# 🗑️ Eliminado: Velocity__x_179.0.asc
# 🗑️ Eliminado: Velocity__x_18.0.asc
# 🗑️ Eliminado: Velocity__x_180.0.asc
# 🗑️ Eliminado: Velocity__x_181.0.asc
# 🗑️ Eliminado: Velocity__x_182.0.asc
# 🗑️ Eliminado: Velocity__x_183.0.asc
# 🗑️ Eliminado: Velocity__x_184.0.asc
# 🗑️ Eliminado: Velocity__x_185.0.asc
# 🗑️ Eliminado: Velocity__x_186.0.asc
# 🗑️ Eliminado: Velocity__x_187.0.asc
# 🗑️ Eliminado: Velocity__x_188.0.asc
# 🗑️ Eliminado: Velocity__x_189.0.asc
# 🗑️ Eliminado: Velocity__x_19.0.asc
# 🗑️ Eliminado: Velocity__x_190.0.asc
# 🗑️ Eliminado: Velocity__x_191.0.asc
# 🗑️ Eliminado: Velocity__x_192.0.asc
# 🗑️ Eliminado: Velocity__x_193.0.asc
# 🗑️ Eliminado: Velocity__x_194.0.asc
# 🗑️ Eliminado: Velocity__x_195.0.asc
# 🗑️ Eliminado: Velocity__x_196.0.asc
# 🗑️ Eliminado: Velocity__x_197.0.asc
# 🗑️ Eliminado: Velocity__x_198.0.asc
# 🗑️ Eliminado: Velocity__x_199.0.asc
# 🗑️ Eliminado: Velocity__x_2.0.asc
# 🗑️ Eliminado: Velocity__x_20.0.asc
# 🗑️ Eliminado: Velocity__x_200.0.asc
# 🗑️ Eliminado: Velocity__x_201.0.asc
# 🗑️ Eliminado: Velocity__x_202.0.asc
# 🗑️ Eliminado: Velocity__x_203.0.asc
# 🗑️ Eliminado: Velocity__x_204.0.asc
# 🗑️ Eliminado: Velocity__x_205.0.asc
# 🗑️ Eliminado: Velocity__x_206.0.asc
# 🗑️ Eliminado: Velocity__x_207.0.asc
# 🗑️ Eliminado: Velocity__x_208.0.asc
# 🗑️ Eliminado: Velocity__x_209.0.asc
# 🗑️ Eliminado: Velocity__x_21.0.asc
# 🗑️ Eliminado: Velocity__x_210.0.asc
# 🗑️ Eliminado: Velocity__x_211.0.asc
# 🗑️ Eliminado: Velocity__x_212.0.asc
# 🗑️ Eliminado: Velocity__x_213.0.asc
# 🗑️ Eliminado: Velocity__x_214.0.asc
# 🗑️ Eliminado: Velocity__x_215.0.asc
# 🗑️ Eliminado: Velocity__x_216.0.asc
# 🗑️ Eliminado: Velocity__x_217.0.asc
# 🗑️ Eliminado: Velocity__x_218.0.asc
# 🗑️ Eliminado: Velocity__x_219.0.asc
# 🗑️ Eliminado: Velocity__x_22.0.asc
# 🗑️ Eliminado: Velocity__x_220.0.asc
# 🗑️ Eliminado: Velocity__x_221.0.asc
# 🗑️ Eliminado: Velocity__x_222.0.asc
# 🗑️ Eliminado: Velocity__x_223.0.asc
# 🗑️ Eliminado: Velocity__x_224.0.asc
# 🗑️ Eliminado: Velocity__x_225.0.asc
# 🗑️ Eliminado: Velocity__x_226.0.asc
# 🗑️ Eliminado: Velocity__x_227.0.asc
# 🗑️ Eliminado: Velocity__x_228.0.asc
# 🗑️ Eliminado: Velocity__x_229.0.asc
# 🗑️ Eliminado: Velocity__x_23.0.asc
# 🗑️ Eliminado: Velocity__x_230.0.asc
# 🗑️ Eliminado: Velocity__x_231.0.asc
# 🗑️ Eliminado: Velocity__x_232.0.asc
# 🗑️ Eliminado: Velocity__x_233.0.asc
# 🗑️ Eliminado: Velocity__x_234.0.asc
# 🗑️ Eliminado: Velocity__x_235.0.asc
# 🗑️ Eliminado: Velocity__x_236.0.asc
# 🗑️ Eliminado: Velocity__x_237.0.asc
# 🗑️ Eliminado: Velocity__x_238.0.asc
# 🗑️ Eliminado: Velocity__x_239.0.asc
# 🗑️ Eliminado: Velocity__x_24.0.asc
# 🗑️ Eliminado: Velocity__x_240.0.asc
# 🗑️ Eliminado: Velocity__x_241.0.asc
# 🗑️ Eliminado: Velocity__x_242.0.asc
# 🗑️ Eliminado: Velocity__x_243.0.asc
# 🗑️ Eliminado: Velocity__x_244.0.asc
# 🗑️ Eliminado: Velocity__x_245.0.asc
# 🗑️ Eliminado: Velocity__x_246.0.asc
# 🗑️ Eliminado: Velocity__x_247.0.asc
# 🗑️ Eliminado: Velocity__x_248.0.asc
# 🗑️ Eliminado: Velocity__x_249.0.asc
# 🗑️ Eliminado: Velocity__x_25.0.asc
# 🗑️ Eliminado: Velocity__x_250.0.asc
# 🗑️ Eliminado: Velocity__x_251.0.asc
# 🗑️ Eliminado: Velocity__x_252.0.asc
# 🗑️ Eliminado: Velocity__x_253.0.asc
# 🗑️ Eliminado: Velocity__x_254.0.asc
# 🗑️ Eliminado: Velocity__x_255.0.asc
# 🗑️ Eliminado: Velocity__x_256.0.asc
# 🗑️ Eliminado: Velocity__x_257.0.asc
# 🗑️ Eliminado: Velocity__x_258.0.asc
# 🗑️ Eliminado: Velocity__x_259.0.asc
# 🗑️ Eliminado: Velocity__x_26.0.asc
# 🗑️ Eliminado: Velocity__x_260.0.asc
# 🗑️ Eliminado: Velocity__x_261.0.asc
# 🗑️ Eliminado: Velocity__x_262.0.asc
# 🗑️ Eliminado: Velocity__x_263.0.asc
# 🗑️ Eliminado: Velocity__x_264.0.asc
# 🗑️ Eliminado: Velocity__x_265.0.asc
# 🗑️ Eliminado: Velocity__x_266.0.asc
# 🗑️ Eliminado: Velocity__x_267.0.asc
# 🗑️ Eliminado: Velocity__x_268.0.asc
# 🗑️ Eliminado: Velocity__x_269.0.asc
# 🗑️ Eliminado: Velocity__x_27.0.asc
# 🗑️ Eliminado: Velocity__x_270.0.asc
# 🗑️ Eliminado: Velocity__x_271.0.asc
# 🗑️ Eliminado: Velocity__x_272.0.asc
# 🗑️ Eliminado: Velocity__x_273.0.asc
# 🗑️ Eliminado: Velocity__x_274.0.asc
# 🗑️ Eliminado: Velocity__x_275.0.asc
# 🗑️ Eliminado: Velocity__x_276.0.asc
# 🗑️ Eliminado: Velocity__x_277.0.asc
# 🗑️ Eliminado: Velocity__x_278.0.asc
# 🗑️ Eliminado: Velocity__x_279.0.asc
# 🗑️ Eliminado: Velocity__x_28.0.asc
# 🗑️ Eliminado: Velocity__x_280.0.asc
# 🗑️ Eliminado: Velocity__x_281.0.asc
# 🗑️ Eliminado: Velocity__x_282.0.asc
# 🗑️ Eliminado: Velocity__x_283.0.asc
# 🗑️ Eliminado: Velocity__x_284.0.asc
# 🗑️ Eliminado: Velocity__x_285.0.asc
# 🗑️ Eliminado: Velocity__x_286.0.asc
# 🗑️ Eliminado: Velocity__x_287.0.asc
# 🗑️ Eliminado: Velocity__x_288.0.asc
# 🗑️ Eliminado: Velocity__x_289.0.asc
# 🗑️ Eliminado: Velocity__x_29.0.asc
# 🗑️ Eliminado: Velocity__x_290.0.asc
# 🗑️ Eliminado: Velocity__x_291.0.asc
# 🗑️ Eliminado: Velocity__x_292.0.asc
# 🗑️ Eliminado: Velocity__x_293.0.asc
# 🗑️ Eliminado: Velocity__x_294.0.asc
# 🗑️ Eliminado: Velocity__x_295.0.asc
# 🗑️ Eliminado: Velocity__x_296.0.asc
# 🗑️ Eliminado: Velocity__x_297.0.asc
# 🗑️ Eliminado: Velocity__x_298.0.asc
# 🗑️ Eliminado: Velocity__x_299.0.asc
# 🗑️ Eliminado: Velocity__x_3.0.asc
# 🗑️ Eliminado: Velocity__x_30.0.asc
# 🗑️ Eliminado: Velocity__x_300.0.asc
# 🗑️ Eliminado: Velocity__x_301.0.asc
# 🗑️ Eliminado: Velocity__x_302.0.asc
# 🗑️ Eliminado: Velocity__x_303.0.asc
# 🗑️ Eliminado: Velocity__x_304.0.asc
# 🗑️ Eliminado: Velocity__x_305.0.asc
# 🗑️ Eliminado: Velocity__x_306.0.asc
# 🗑️ Eliminado: Velocity__x_307.0.asc
# 🗑️ Eliminado: Velocity__x_308.0.asc
# 🗑️ Eliminado: Velocity__x_309.0.asc
# 🗑️ Eliminado: Velocity__x_31.0.asc
# 🗑️ Eliminado: Velocity__x_310.0.asc
# 🗑️ Eliminado: Velocity__x_311.0.asc
# 🗑️ Eliminado: Velocity__x_312.0.asc
# 🗑️ Eliminado: Velocity__x_313.0.asc
# 🗑️ Eliminado: Velocity__x_314.0.asc
# 🗑️ Eliminado: Velocity__x_315.0.asc
# 🗑️ Eliminado: Velocity__x_316.0.asc
# 🗑️ Eliminado: Velocity__x_317.0.asc
# 🗑️ Eliminado: Velocity__x_318.0.asc
# 🗑️ Eliminado: Velocity__x_319.0.asc
# 🗑️ Eliminado: Velocity__x_32.0.asc
# 🗑️ Eliminado: Velocity__x_320.0.asc
# 🗑️ Eliminado: Velocity__x_321.0.asc
# 🗑️ Eliminado: Velocity__x_322.0.asc
# 🗑️ Eliminado: Velocity__x_323.0.asc
# 🗑️ Eliminado: Velocity__x_324.0.asc
# 🗑️ Eliminado: Velocity__x_325.0.asc
# 🗑️ Eliminado: Velocity__x_326.0.asc
# 🗑️ Eliminado: Velocity__x_327.0.asc
# 🗑️ Eliminado: Velocity__x_328.0.asc
# 🗑️ Eliminado: Velocity__x_329.0.asc
# 🗑️ Eliminado: Velocity__x_33.0.asc
# 🗑️ Eliminado: Velocity__x_330.0.asc
# 🗑️ Eliminado: Velocity__x_331.0.asc
# 🗑️ Eliminado: Velocity__x_332.0.asc
# 🗑️ Eliminado: Velocity__x_333.0.asc
# 🗑️ Eliminado: Velocity__x_334.0.asc
# 🗑️ Eliminado: Velocity__x_335.0.asc
# 🗑️ Eliminado: Velocity__x_336.0.asc
# 🗑️ Eliminado: Velocity__x_337.0.asc
# 🗑️ Eliminado: Velocity__x_338.0.asc
# 🗑️ Eliminado: Velocity__x_339.0.asc
# 🗑️ Eliminado: Velocity__x_34.0.asc
# 🗑️ Eliminado: Velocity__x_340.0.asc
# 🗑️ Eliminado: Velocity__x_341.0.asc
# 🗑️ Eliminado: Velocity__x_342.0.asc
# 🗑️ Eliminado: Velocity__x_343.0.asc
# 🗑️ Eliminado: Velocity__x_344.0.asc
# 🗑️ Eliminado: Velocity__x_345.0.asc
# 🗑️ Eliminado: Velocity__x_346.0.asc
# 🗑️ Eliminado: Velocity__x_347.0.asc
# 🗑️ Eliminado: Velocity__x_348.0.asc
# 🗑️ Eliminado: Velocity__x_349.0.asc
# 🗑️ Eliminado: Velocity__x_35.0.asc
# 🗑️ Eliminado: Velocity__x_350.0.asc
# 🗑️ Eliminado: Velocity__x_36.0.asc
# 🗑️ Eliminado: Velocity__x_37.0.asc
# 🗑️ Eliminado: Velocity__x_38.0.asc
# 🗑️ Eliminado: Velocity__x_39.0.asc
# 🗑️ Eliminado: Velocity__x_4.0.asc
# 🗑️ Eliminado: Velocity__x_40.0.asc
# 🗑️ Eliminado: Velocity__x_41.0.asc
# 🗑️ Eliminado: Velocity__x_42.0.asc
# 🗑️ Eliminado: Velocity__x_43.0.asc
# 🗑️ Eliminado: Velocity__x_44.0.asc
# 🗑️ Eliminado: Velocity__x_45.0.asc
# 🗑️ Eliminado: Velocity__x_46.0.asc
# 🗑️ Eliminado: Velocity__x_47.0.asc
# 🗑️ Eliminado: Velocity__x_48.0.asc
# 🗑️ Eliminado: Velocity__x_49.0.asc
# 🗑️ Eliminado: Velocity__x_5.0.asc
# 🗑️ Eliminado: Velocity__x_50.0.asc
# 🗑️ Eliminado: Velocity__x_51.0.asc
# 🗑️ Eliminado: Velocity__x_52.0.asc
# 🗑️ Eliminado: Velocity__x_53.0.asc
# 🗑️ Eliminado: Velocity__x_54.0.asc
# 🗑️ Eliminado: Velocity__x_55.0.asc
# 🗑️ Eliminado: Velocity__x_56.0.asc
# 🗑️ Eliminado: Velocity__x_57.0.asc
# 🗑️ Eliminado: Velocity__x_58.0.asc
# 🗑️ Eliminado: Velocity__x_59.0.asc
# 🗑️ Eliminado: Velocity__x_6.0.asc
# 🗑️ Eliminado: Velocity__x_60.0.asc
# 🗑️ Eliminado: Velocity__x_61.0.asc
# 🗑️ Eliminado: Velocity__x_62.0.asc
# 🗑️ Eliminado: Velocity__x_63.0.asc
# 🗑️ Eliminado: Velocity__x_64.0.asc
# 🗑️ Eliminado: Velocity__x_65.0.asc
# 🗑️ Eliminado: Velocity__x_66.0.asc
# 🗑️ Eliminado: Velocity__x_67.0.asc
# 🗑️ Eliminado: Velocity__x_68.0.asc
# 🗑️ Eliminado: Velocity__x_69.0.asc
# 🗑️ Eliminado: Velocity__x_7.0.asc
# 🗑️ Eliminado: Velocity__x_70.0.asc
# 🗑️ Eliminado: Velocity__x_71.0.asc
# 🗑️ Eliminado: Velocity__x_72.0.asc
# 🗑️ Eliminado: Velocity__x_73.0.asc
# 🗑️ Eliminado: Velocity__x_74.0.asc
# 🗑️ Eliminado: Velocity__x_75.0.asc
# 🗑️ Eliminado: Velocity__x_76.0.asc
# 🗑️ Eliminado: Velocity__x_77.0.asc
# 🗑️ Eliminado: Velocity__x_78.0.asc
# 📂 Copiado: Velocity____53.0.asc
# 📂 Copiado: Velocity____54.0.asc
# 📂 Copiado: Velocity____55.0.asc
# 📂 Copiado: Velocity____56.0.asc
# 📂 Copiado: Velocity____57.0.asc
# 📂 Copiado: Velocity____58.0.asc
# 📂 Copiado: Velocity____59.0.asc
# 📂 Copiado: Velocity____6.0.asc
# 📂 Copiado: Velocity____60.0.asc
# 📂 Copiado: Velocity____61.0.asc
# 📂 Copiado: Velocity____62.0.asc
# 📂 Copiado: Velocity____63.0.asc
# 📂 Copiado: Velocity____64.0.asc
# 📂 Copiado: Velocity____65.0.asc
# 📂 Copiado: Velocity____66.0.asc
# 📂 Copiado: Velocity____67.0.asc
# 📂 Copiado: Velocity____68.0.asc
# 📂 Copiado: Velocity____69.0.asc
# 📂 Copiado: Velocity____7.0.asc
# 📂 Copiado: Velocity____70.0.asc
# 📂 Copiado: Velocity____71.0.asc
# 📂 Copiado: Velocity____72.0.asc
# 📂 Copiado: Velocity____73.0.asc
# 📂 Copiado: Velocity____74.0.asc
# 📂 Copiado: Velocity____75.0.asc
# 📂 Copiado: Velocity____76.0.asc
# 📂 Copiado: Velocity____77.0.asc
# 📂 Copiado: Velocity____78.0.asc
# 📂 Copiado: Velocity____79.0.asc
# 📂 Copiado: Velocity____8.0.asc
# 📂 Copiado: Velocity____80.0.asc
# 📂 Copiado: Velocity____81.0.asc
# 📂 Copiado: Velocity____82.0.asc
# 📂 Copiado: Velocity____83.0.asc
# 📂 Copiado: Velocity____84.0.asc
# 📂 Copiado: Velocity____85.0.asc
# 📂 Copiado: Velocity____86.0.asc
# 📂 Copiado: Velocity____87.0.asc
# 📂 Copiado: Velocity____88.0.asc
# 📂 Copiado: Velocity____89.0.asc
# 📂 Copiado: Velocity____9.0.asc
# 📂 Copiado: Velocity____90.0.asc
# 📂 Copiado: Velocity____91.0.asc
# 📂 Copiado: Velocity____92.0.asc
# 📂 Copiado: Velocity____93.0.asc
# 📂 Copiado: Velocity____94.0.asc
# 📂 Copiado: Velocity____95.0.asc
# 📂 Copiado: Velocity____96.0.asc
# 📂 Copiado: Velocity____97.0.asc
# 📂 Copiado: Velocity____98.0.asc
# 📂 Copiado: Velocity____99.0.asc
#
# 🎨 Generando la leyenda...
# ✅ Leyenda guardada en G:\Floods-WebMap\aux_images\legend.png
#
# ✅ Todos los archivos han sido copiados en G:/Floods-WebMap.

# %%
cd G:/Floods-WebMap
# Out:
# G:\Floods-WebMap

# %%
# !git add simulation_files/png
# !git add simulation_files/asc
# !git add aux_images/legend.png
# !git commit -m "Actualización de imágenes PNG, archivos ASC y leyenda en aux_images (sin eliminar previos)"
# !git push origin main
# Out:
# [main e792c06] ActualizaciÃ³n de imÃ¡genes PNG, archivos ASC y leyenda en aux_images (sin eliminar previos)
#  2088 files changed, 120744 insertions(+), 341600 deletions(-)
#  delete mode 100644 simulation_files/asc/.DS_Store
#  delete mode 100755 simulation_files/asc/Depth____0.0.asc
#  create mode 100644 simulation_files/asc/Depth____000000.asc
#  delete mode 100755 simulation_files/asc/Depth____930.0.asc
#  delete mode 100755 simulation_files/asc/Depth____935.0.asc
#  delete mode 100755 simulation_files/asc/Depth____940.0.asc
#  delete mode 100755 simulation_files/asc/Depth____945.0.asc
#  delete mode 100755 simulation_files/asc/Depth____95.0.asc
#  delete mode 100755 simulation_files/asc/Depth____950.0.asc
#  delete mode 100755 simulation_files/asc/Depth____955.0.asc
#  delete mode 100755 simulation_files/asc/Depth____960.0.asc
#  delete mode 100755 simulation_files/asc/Depth____965.0.asc
#  delete mode 100755 simulation_files/asc/Depth____970.0.asc
#  delete mode 100755 simulation_files/asc/Depth____975.0.asc
#  delete mode 100755 simulation_files/asc/Depth____980.0.asc
#  delete mode 100755 simulation_files/asc/Depth____985.0.asc
#  delete mode 100755 simulation_files/asc/Depth____990.0.asc
#  delete mode 100755 simulation_files/asc/Depth____995.0.asc
#  create mode 100644 simulation_files/asc/Velocity____0.0.asc
#  create mode 100644 simulation_files/asc/Velocity____1.0.asc
#  create mode 100644 simulation_files/asc/Velocity____10.0.asc
#  create mode 100644 simulation_files/asc/Velocity____100.0.asc
#  create mode 100644 simulation_files/asc/Velocity____101.0.asc
#  create mode 100644 simulation_files/asc/Velocity____102.0.asc
#  create mode 100644 simulation_files/asc/Velocity____103.0.asc
#  create mode 100644 simulation_files/asc/Velocity____104.0.asc
#  create mode 100644 simulation_files/asc/Velocity____105.0.asc
#  create mode 100644 simulation_files/asc/Velocity____106.0.asc
#  create mode 100644 simulation_files/asc/Velocity____107.0.asc
#  create mode 100644 simulation_files/asc/Velocity____108.0.asc
#  create mode 100644 simulation_files/asc/Velocity____109.0.asc
#  create mode 100644 simulation_files/asc/Velocity____11.0.asc
#  create mode 100644 simulation_files/asc/Velocity____110.0.asc
#  create mode 100644 simulation_files/asc/Velocity____111.0.asc
#  create mode 100644 simulation_files/asc/Velocity____112.0.asc
#  create mode 100644 simulation_files/asc/Velocity____113.0.asc
#  create mode 100644 simulation_files/asc/Velocity____114.0.asc
#  create mode 100644 simulation_files/asc/Velocity____115.0.asc
#  create mode 100644 simulation_files/asc/Velocity____116.0.asc
#  create mode 100644 simulation_files/asc/Velocity____117.0.asc
#  create mode 100644 simulation_files/asc/Velocity____118.0.asc
#  create mode 100644 simulation_files/asc/Velocity____119.0.asc
#  create mode 100644 simulation_files/asc/Velocity____12.0.asc
#  create mode 100644 simulation_files/asc/Velocity____120.0.asc
#  create mode 100644 simulation_files/asc/Velocity____121.0.asc
#  create mode 100644 simulation_files/asc/Velocity____122.0.asc
#  create mode 100644 simulation_files/asc/Velocity____123.0.asc
#  create mode 100644 simulation_files/asc/Velocity____124.0.asc
#  create mode 100644 simulation_files/asc/Velocity____125.0.asc
#  create mode 100644 simulation_files/asc/Velocity____126.0.asc
#  create mode 100644 simulation_files/asc/Velocity____127.0.asc
#  create mode 100644 simulation_files/asc/Velocity____128.0.asc
#  create mode 100644 simulation_files/asc/Velocity____129.0.asc
#  create mode 100644 simulation_files/asc/Velocity____13.0.asc
#  create mode 100644 simulation_files/asc/Velocity____130.0.asc
#  create mode 100644 simulation_files/asc/Velocity____131.0.asc
#  create mode 100644 simulation_files/asc/Velocity____132.0.asc
#  create mode 100644 simulation_files/asc/Velocity____133.0.asc
#  create mode 100644 simulation_files/asc/Velocity____134.0.asc
#  create mode 100644 simulation_files/asc/Velocity____135.0.asc
#  create mode 100644 simulation_files/asc/Velocity____136.0.asc
#  create mode 100644 simulation_files/asc/Velocity____137.0.asc
#  create mode 100644 simulation_files/asc/Velocity____138.0.asc
#  create mode 100644 simulation_files/asc/Velocity____139.0.asc
#  create mode 100644 simulation_files/asc/Velocity____14.0.asc
#  create mode 100644 simulation_files/asc/Velocity____140.0.asc
#  create mode 100644 simulation_files/asc/Velocity____141.0.asc
#  create mode 100644 simulation_files/asc/Velocity____142.0.asc
#  create mode 100644 simulation_files/asc/Velocity____143.0.asc
#  create mode 100644 simulation_files/asc/Velocity____144.0.asc
#  create mode 100644 simulation_files/asc/Velocity____145.0.asc
#  create mode 100644 simulation_files/asc/Velocity____146.0.asc
#  create mode 100644 simulation_files/asc/Velocity____147.0.asc
#  create mode 100644 simulation_files/asc/Velocity____148.0.asc
#  create mode 100644 simulation_files/asc/Velocity____149.0.asc
#  create mode 100644 simulation_files/asc/Velocity____15.0.asc
#  create mode 100644 simulation_files/asc/Velocity____150.0.asc
#  create mode 100644 simulation_files/asc/Velocity____151.0.asc
#  create mode 100644 simulation_files/asc/Velocity____152.0.asc
#  create mode 100644 simulation_files/asc/Velocity____153.0.asc
#  create mode 100644 simulation_files/asc/Velocity____154.0.asc
#  create mode 100644 simulation_files/asc/Velocity____155.0.asc
#  create mode 100644 simulation_files/asc/Velocity____156.0.asc
#  create mode 100644 simulation_files/asc/Velocity____157.0.asc
#  create mode 100644 simulation_files/asc/Velocity____158.0.asc
#  create mode 100644 simulation_files/asc/Velocity____159.0.asc
#  create mode 100644 simulation_files/asc/Velocity____16.0.asc
#  create mode 100644 simulation_files/asc/Velocity____160.0.asc
#  create mode 100644 simulation_files/asc/Velocity____161.0.asc
#  create mode 100644 simulation_files/asc/Velocity____162.0.asc
#  create mode 100644 simulation_files/asc/Velocity____163.0.asc
#  create mode 100644 simulation_files/asc/Velocity____164.0.asc
#  create mode 100644 simulation_files/asc/Velocity____165.0.asc
#  create mode 100644 simulation_files/asc/Velocity____166.0.asc
#  create mode 100644 simulation_files/asc/Velocity____167.0.asc
#  create mode 100644 simulation_files/asc/Velocity____168.0.asc
#  create mode 100644 simulation_files/asc/Velocity____169.0.asc
#  create mode 100644 simulation_files/asc/Velocity____17.0.asc
#  create mode 100644 simulation_files/asc/Velocity____170.0.asc
#  create mode 100644 simulation_files/asc/Velocity____171.0.asc
#  create mode 100644 simulation_files/asc/Velocity____172.0.asc
#  create mode 100644 simulation_files/asc/Velocity____173.0.asc
#  create mode 100644 simulation_files/asc/Velocity____174.0.asc
#  create mode 100644 simulation_files/asc/Velocity____175.0.asc
#  create mode 100644 simulation_files/asc/Velocity____176.0.asc
#  create mode 100644 simulation_files/asc/Velocity____177.0.asc
#  create mode 100644 simulation_files/asc/Velocity____178.0.asc
#  create mode 100644 simulation_files/asc/Velocity____179.0.asc
#  create mode 100644 simulation_files/asc/Velocity____18.0.asc
#  create mode 100644 simulation_files/asc/Velocity____180.0.asc
#  create mode 100644 simulation_files/asc/Velocity____181.0.asc
#  create mode 100644 simulation_files/asc/Velocity____182.0.asc
#  create mode 100644 simulation_files/asc/Velocity____183.0.asc
#  create mode 100644 simulation_files/asc/Velocity____184.0.asc
#  create mode 100644 simulation_files/asc/Velocity____185.0.asc
#  create mode 100644 simulation_files/asc/Velocity____186.0.asc
#  create mode 100644 simulation_files/asc/Velocity____187.0.asc
#  create mode 100644 simulation_files/asc/Velocity____188.0.asc
#  create mode 100644 simulation_files/asc/Velocity____189.0.asc
#  create mode 100644 simulation_files/asc/Velocity____19.0.asc
#  create mode 100644 simulation_files/asc/Velocity____190.0.asc
#  create mode 100644 simulation_files/asc/Velocity____191.0.asc
#  create mode 100644 simulation_files/asc/Velocity____192.0.asc
#  create mode 100644 simulation_files/asc/Velocity____193.0.asc
#  create mode 100644 simulation_files/asc/Velocity____194.0.asc
#  create mode 100644 simulation_files/asc/Velocity____195.0.asc
#  create mode 100644 simulation_files/asc/Velocity____196.0.asc
#  create mode 100644 simulation_files/asc/Velocity____197.0.asc
#  create mode 100644 simulation_files/asc/Velocity____198.0.asc
#  create mode 100644 simulation_files/asc/Velocity____199.0.asc
#  create mode 100644 simulation_files/asc/Velocity____2.0.asc
#  create mode 100644 simulation_files/asc/Velocity____20.0.asc
#  create mode 100644 simulation_files/asc/Velocity____200.0.asc
#  create mode 100644 simulation_files/asc/Velocity____201.0.asc
#  create mode 100644 simulation_files/asc/Velocity____202.0.asc
#  create mode 100644 simulation_files/asc/Velocity____203.0.asc
#  create mode 100644 simulation_files/asc/Velocity____204.0.asc
#  create mode 100644 simulation_files/asc/Velocity____205.0.asc
#  create mode 100644 simulation_files/asc/Velocity____206.0.asc
#  create mode 100644 simulation_files/asc/Velocity____207.0.asc
#  create mode 100644 simulation_files/asc/Velocity____208.0.asc
#  create mode 100644 simulation_files/asc/Velocity____209.0.asc
#  create mode 100644 simulation_files/asc/Velocity____21.0.asc
#  create mode 100644 simulation_files/asc/Velocity____210.0.asc
#  create mode 100644 simulation_files/asc/Velocity____211.0.asc
#  create mode 100644 simulation_files/asc/Velocity____212.0.asc
#  create mode 100644 simulation_files/asc/Velocity____213.0.asc
#  create mode 100644 simulation_files/asc/Velocity____214.0.asc
#  create mode 100644 simulation_files/asc/Velocity____215.0.asc
#  create mode 100644 simulation_files/asc/Velocity____216.0.asc
#  create mode 100644 simulation_files/asc/Velocity____217.0.asc
#  create mode 100644 simulation_files/asc/Velocity____218.0.asc
#  create mode 100644 simulation_files/asc/Velocity____219.0.asc
#  create mode 100644 simulation_files/asc/Velocity____22.0.asc
#  create mode 100644 simulation_files/asc/Velocity____220.0.asc
#  create mode 100644 simulation_files/asc/Velocity____221.0.asc
#  create mode 100644 simulation_files/asc/Velocity____222.0.asc
#  create mode 100644 simulation_files/asc/Velocity____223.0.asc
#  create mode 100644 simulation_files/asc/Velocity____224.0.asc
#  create mode 100644 simulation_files/asc/Velocity____225.0.asc
#  create mode 100644 simulation_files/asc/Velocity____226.0.asc
#  create mode 100644 simulation_files/asc/Velocity____227.0.asc
#  create mode 100644 simulation_files/asc/Velocity____228.0.asc
#  create mode 100644 simulation_files/asc/Velocity____229.0.asc
#  create mode 100644 simulation_files/asc/Velocity____23.0.asc
#  create mode 100644 simulation_files/asc/Velocity____230.0.asc
#  create mode 100644 simulation_files/asc/Velocity____231.0.asc
#  create mode 100644 simulation_files/asc/Velocity____232.0.asc
#  create mode 100644 simulation_files/asc/Velocity____233.0.asc
#  create mode 100644 simulation_files/asc/Velocity____234.0.asc
#  create mode 100644 simulation_files/asc/Velocity____235.0.asc
#  create mode 100644 simulation_files/asc/Velocity____236.0.asc
#  create mode 100644 simulation_files/asc/Velocity____237.0.asc
#  create mode 100644 simulation_files/asc/Velocity____238.0.asc
#  create mode 100644 simulation_files/asc/Velocity____239.0.asc
#  create mode 100644 simulation_files/asc/Velocity____24.0.asc
#  create mode 100644 simulation_files/asc/Velocity____240.0.asc
#  create mode 100644 simulation_files/asc/Velocity____241.0.asc
#  create mode 100644 simulation_files/asc/Velocity____242.0.asc
#  create mode 100644 simulation_files/asc/Velocity____243.0.asc
#  create mode 100644 simulation_files/asc/Velocity____244.0.asc
#  create mode 100644 simulation_files/asc/Velocity____245.0.asc
#  create mode 100644 simulation_files/asc/Velocity____246.0.asc
#  create mode 100644 simulation_files/asc/Velocity____247.0.asc
#  create mode 100644 simulation_files/asc/Velocity____248.0.asc
#  create mode 100644 simulation_files/asc/Velocity____249.0.asc
#  create mode 100644 simulation_files/asc/Velocity____25.0.asc
#  create mode 100644 simulation_files/asc/Velocity____250.0.asc
#  create mode 100644 simulation_files/asc/Velocity____251.0.asc
#  create mode 100644 simulation_files/asc/Velocity____252.0.asc
#  create mode 100644 simulation_files/asc/Velocity____253.0.asc
#  create mode 100644 simulation_files/asc/Velocity____254.0.asc
#  create mode 100644 simulation_files/asc/Velocity____255.0.asc
#  create mode 100644 simulation_files/asc/Velocity____256.0.asc
#  create mode 100644 simulation_files/asc/Velocity____257.0.asc
#  create mode 100644 simulation_files/asc/Velocity____258.0.asc
#  create mode 100644 simulation_files/asc/Velocity____259.0.asc
#  create mode 100644 simulation_files/asc/Velocity____26.0.asc
#  create mode 100644 simulation_files/asc/Velocity____260.0.asc
#  create mode 100644 simulation_files/asc/Velocity____261.0.asc
#  create mode 100644 simulation_files/asc/Velocity____262.0.asc
#  create mode 100644 simulation_files/asc/Velocity____263.0.asc
#  create mode 100644 simulation_files/asc/Velocity____264.0.asc
#  create mode 100644 simulation_files/asc/Velocity____265.0.asc
#  create mode 100644 simulation_files/asc/Velocity____266.0.asc
#  create mode 100644 simulation_files/asc/Velocity____267.0.asc
#  create mode 100644 simulation_files/asc/Velocity____268.0.asc
#  create mode 100644 simulation_files/asc/Velocity____269.0.asc
#  create mode 100644 simulation_files/asc/Velocity____27.0.asc
#  create mode 100644 simulation_files/asc/Velocity____270.0.asc
#  create mode 100644 simulation_files/asc/Velocity____271.0.asc
#  create mode 100644 simulation_files/asc/Velocity____272.0.asc
#  create mode 100644 simulation_files/asc/Velocity____273.0.asc
#  create mode 100644 simulation_files/asc/Velocity____274.0.asc
#  create mode 100644 simulation_files/asc/Velocity____275.0.asc
#  create mode 100644 simulation_files/asc/Velocity____276.0.asc
#  create mode 100644 simulation_files/asc/Velocity____277.0.asc
#  create mode 100644 simulation_files/asc/Velocity____278.0.asc
#  create mode 100644 simulation_files/asc/Velocity____279.0.asc
#  create mode 100644 simulation_files/asc/Velocity____28.0.asc
#  create mode 100644 simulation_files/asc/Velocity____280.0.asc
#  create mode 100644 simulation_files/asc/Velocity____281.0.asc
#  create mode 100644 simulation_files/asc/Velocity____282.0.asc
#  create mode 100644 simulation_files/asc/Velocity____283.0.asc
#  create mode 100644 simulation_files/asc/Velocity____284.0.asc
#  create mode 100644 simulation_files/asc/Velocity____285.0.asc
#  create mode 100644 simulation_files/asc/Velocity____286.0.asc
#  create mode 100644 simulation_files/asc/Velocity____287.0.asc
#  create mode 100644 simulation_files/asc/Velocity____288.0.asc
#  create mode 100644 simulation_files/asc/Velocity____289.0.asc
#  create mode 100644 simulation_files/asc/Velocity____29.0.asc
#  create mode 100644 simulation_files/asc/Velocity____290.0.asc
#  create mode 100644 simulation_files/asc/Velocity____291.0.asc
#  create mode 100644 simulation_files/asc/Velocity____292.0.asc
#  create mode 100644 simulation_files/asc/Velocity____293.0.asc
#  create mode 100644 simulation_files/asc/Velocity____294.0.asc
#  create mode 100644 simulation_files/asc/Velocity____295.0.asc
#  create mode 100644 simulation_files/asc/Velocity____296.0.asc
#  create mode 100644 simulation_files/asc/Velocity____297.0.asc
#  create mode 100644 simulation_files/asc/Velocity____298.0.asc
#  create mode 100644 simulation_files/asc/Velocity____299.0.asc
#  create mode 100644 simulation_files/asc/Velocity____3.0.asc
#  create mode 100644 simulation_files/asc/Velocity____30.0.asc
#  create mode 100644 simulation_files/asc/Velocity____300.0.asc
#  create mode 100644 simulation_files/asc/Velocity____301.0.asc
#  create mode 100644 simulation_files/asc/Velocity____302.0.asc
# ...
#  create mode 100644 simulation_files/png/Depth_000171.png
#  create mode 100644 simulation_files/png/Depth_000172.png
#  create mode 100644 simulation_files/png/Depth_000173.png
#  create mode 100644 simulation_files/png/Depth_000174.png
#  create mode 100644 simulation_files/png/Depth_000176.png
#  create mode 100644 simulation_files/png/Depth_000177.png
#  create mode 100644 simulation_files/png/Depth_000178.png
#  create mode 100644 simulation_files/png/Depth_000179.png
#  create mode 100644 simulation_files/png/Depth_000181.png
#  create mode 100644 simulation_files/png/Depth_000182.png
#  create mode 100644 simulation_files/png/Depth_000183.png
#  create mode 100644 simulation_files/png/Depth_000184.png
#  create mode 100644 simulation_files/png/Depth_000186.png
#  create mode 100644 simulation_files/png/Depth_000187.png
#  delete mode 100644 simulation_files/png/Depth_000865.png
#  delete mode 100644 simulation_files/png/Depth_000870.png
#  delete mode 100644 simulation_files/png/Depth_000875.png
#  delete mode 100644 simulation_files/png/Depth_000880.png
#  delete mode 100644 simulation_files/png/Depth_000885.png
#  delete mode 100644 simulation_files/png/Depth_000890.png
#  delete mode 100644 simulation_files/png/Depth_000895.png
#  delete mode 100644 simulation_files/png/Depth_000900.png
#  delete mode 100644 simulation_files/png/Depth_000905.png
#  delete mode 100644 simulation_files/png/Depth_000910.png
#  delete mode 100644 simulation_files/png/Depth_000915.png
#  delete mode 100644 simulation_files/png/Depth_000920.png
#  delete mode 100644 simulation_files/png/Depth_000925.png
#  delete mode 100644 simulation_files/png/Depth_000930.png
#  delete mode 100644 simulation_files/png/Depth_000935.png
#  delete mode 100644 simulation_files/png/Depth_000940.png
#  delete mode 100644 simulation_files/png/Depth_000945.png
#  delete mode 100644 simulation_files/png/Depth_000950.png
#  delete mode 100644 simulation_files/png/Depth_000955.png
#  delete mode 100644 simulation_files/png/Depth_000960.png
#  delete mode 100644 simulation_files/png/Depth_000965.png
#  delete mode 100644 simulation_files/png/Depth_000970.png
#  delete mode 100644 simulation_files/png/Depth_000975.png
#  delete mode 100644 simulation_files/png/Depth_000980.png
#  delete mode 100644 simulation_files/png/Depth_000985.png
#  delete mode 100644 simulation_files/png/Depth_000990.png
#  delete mode 100644 simulation_files/png/Depth_000995.png
#  delete mode 100644 simulation_files/png/Depth_001000.png
# To https://github.com/cgotelli/Floods-WebMap.git
#    42fdb2b..e792c06  main -> main

# %%
# ========================================
# Example snippet for build_map.ipynb
# Updated to include two animation layers and allow customization of the HTML title and layer names.
# Only Animation Layer 1 is active by default.
# ========================================

output_html_filename = "my_map.html"

# User-defined variables for customization:
html_title = "My Custom Map Title"           # Title of the HTML page
animation_layer_name = "Animation Layer 1"    # Name for the first animation layer
animation_layer2_name = "Animation Layer 2"   # Name for the second animation layer
drawings_layer_name = "Drawings Layer"        # Name for the drawings layer

# Define the GitHub folder URL (the one seen in the browser)
github_url = "https://github.com/cgotelli/Floods-WebMap/tree/main/simulation_files/png"

# Legend image location in the new repo:
legend_url = "https://github.com/cgotelli/Floods-WebMap/raw/refs/heads/main/aux_images/legend.png"

default_zoom = 15
overlay_opacity = 0.75
start_year = 2025
start_month = 1
start_day = 1

# Convert the GitHub URL to the corresponding API URL.
# GitHub URL format:
#   https://github.com/{user}/{repo}/tree/{branch}/{path}
# API URL format:
#   https://api.github.com/repos/{user}/{repo}/contents/{path}
if "github.com" in github_url:
    # Remove the "https://github.com/" prefix.
    path_part = github_url.replace("https://github.com/", "")
    # Split the remaining part.
    parts = path_part.split("/")
    # Expecting parts to be: [user, repo, "tree", branch, path...]
    if len(parts) >= 5 and parts[2] == "tree":
        user = parts[0]
        repo = parts[1]
        branch = parts[3]  # branch is not used in API URL
        folder_path = "/".join(parts[4:])
        folder_url = f"https://api.github.com/repos/{user}/{repo}/contents/{folder_path}"
    else:
        # Fallback to the provided URL if the format is unexpected
        folder_url = github_url
else:
    folder_url = github_url

# Suppose we've computed bounding_boxes from the ASC->PNG script.
# We'll use the first bounding box for demonstration:
if 'bounding_boxes' in globals() and bounding_boxes:
    # bounding_boxes[i] => (output_png_name, (lat_bottom, lon_left, lat_top, lon_right))
    _, (lat_bottom, lon_left, lat_top, lon_right) = bounding_boxes[0]
else:
    # Fallback or default values
    lat_bottom, lon_left, lat_top, lon_right = 46.5199, 6.6309, 46.5211, 6.6363

# Build the JavaScript strings for the Leaflet bounds and center.
imageBounds_str = f"[[{lat_bottom}, {lon_left}], [{lat_top}, {lon_right}]]"
center_lat = 0.5 * (lat_bottom + lat_top)
center_lon = 0.5 * (lon_left + lon_right)
mapCenter_str = f"[{center_lat:.5f}, {center_lon:.5f}]"

# Start date for frames (JS-compatible)
startDateJS = f"new Date('{start_year:04d}-{start_month:02d}-{start_day:02d}T00:00:00Z')"

# Build the HTML content with all text in English and customized title and layer names.
html_content = f"""<!DOCTYPE html>
<html>
<head>
  <title>{html_title}</title>
  <meta charset="utf-8"/>
  <!-- CSS: Leaflet -->
  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.5.1/dist/leaflet.css" />
  <!-- CSS: Leaflet TimeDimension -->
  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.min.css" />
  <!-- CSS: Leaflet Measure -->
  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet-measure@3.1.0/dist/leaflet-measure.min.css">
  <!-- CSS: Leaflet.draw (v0.4.2) -->
  <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/0.4.2/leaflet.draw.css"/>
  <!-- CSS: FontAwesome for icons -->
  <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
  <style>
    #map {{
      position: relative;
      width: 100%;
      height: 600px;
    }}
  </style>
</head>
<body>
  <div id="map">
    <!-- Legend in the lower-right corner -->
    <div id="legend" style="position: absolute; bottom: 15px; right: 10px; background: rgba(255,255,255,0); padding: 5px; border: 0px solid #ccc; z-index: 1000;">
      <img src="{legend_url}" alt="Depth Legend">
    </div>
  </div>
  
  <!-- JS: Leaflet, Iso8601, TimeDimension, Measure, Leaflet.draw -->
  <script src="https://cdn.jsdelivr.net/npm/leaflet@1.5.1/dist/leaflet.js"></script>
  <script src="https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js"></script>
  <script src="https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js"></script>
  <script src="https://cdn.jsdelivr.net/npm/leaflet-measure@3.1.0/dist/leaflet-measure.min.js"></script>
  <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/0.4.2/leaflet.draw.js"></script>
  
  <script>
    /*************************************************
     * preloadImages: loads all image URLs in parallel
     *************************************************/
    function preloadImages(urls, callback) {{
      let loadedCount = 0;
      const total = urls.length;
      urls.forEach(url => {{
        const img = new Image();
        img.onload = img.onerror = function() {{
          loadedCount++;
          if (loadedCount === total) {{
            callback(urls);
          }}
        }};
        img.src = url;
      }});
    }}
    
    /*************************************************
     * getPNGFilesFromGitHubFolder: fetch Depth_*.png from new repo
     *************************************************/
    function getPNGFilesFromGitHubFolder(folderUrl, callback) {{
      fetch(folderUrl)
        .then(response => response.json())
        .then(json => {{
          let pngFiles = json.filter(item => 
            item.type === "file" && item.name.toLowerCase().startsWith("depth")
          ).map(item => item.download_url);
          pngFiles.sort();
          callback(pngFiles);
        }})
        .catch(error => {{
          console.error("Error fetching GitHub folder:", error);
          callback([]);
        }});
    }}
    
    /*************************************************
     * Subclass for ImageOverlay in TimeDimension
     *************************************************/
    L.TimeDimension.Layer.ImageOverlay = L.TimeDimension.Layer.extend({{
      initialize: function(layer, options) {{
        L.TimeDimension.Layer.prototype.initialize.call(this, layer, options);
        if (typeof this.options.time === 'string') {{
          this._time = new Date(this.options.time).getTime();
        }} else if (this.options.time instanceof Date) {{
          this._time = this.options.time.getTime();
        }} else {{
          this._time = this.options.time;
        }}
      }},
      _onNewTimeLoading: function(ev) {{
        this.fire('timeload', {{ time: ev.time }});
      }},
      isReady: function(time) {{
        return true;
      }},
      _update: function() {{
        if (!this._map) return;
        var currentTime = this._timeDimension.getCurrentTime();
        var tolerance = 500;
        console.log("Overlay time: " + this._time + ", currentTime: " + currentTime);
        if (Math.abs(currentTime - this._time) < tolerance) {{
          if (!this._map.hasLayer(this._baseLayer)) {{
            console.log("Adding overlay for time " + this._time);
            this._map.addLayer(this._baseLayer);
          }}
        }} else {{
          if (this._map.hasLayer(this._baseLayer)) {{
            console.log("Removing overlay for time " + this._time);
            this._map.removeLayer(this._baseLayer);
          }}
        }}
        return true;
      }}
    }});
    L.timeDimension.layer.imageOverlay = function(layer, options) {{
      return new L.TimeDimension.Layer.ImageOverlay(layer, options);
    }};
    
    /*************************************************
     * Initialization
     *************************************************/
    var folderUrl = "{folder_url}";
    
    getPNGFilesFromGitHubFolder(folderUrl, function(pngFiles) {{
      console.log("Obtained PNG URLs:", pngFiles);
      
      preloadImages(pngFiles, function(loadedUrls) {{
        console.log("All images have been preloaded.");
        
        var times = [];
        var startTime = {startDateJS};
        for (var i = 0; i < loadedUrls.length; i++) {{
          var time = new Date(startTime.getTime() + i * 1000);
          times.push(time.toISOString());
        }}
        
        var imageBounds = {imageBounds_str};
        var mapCenter = {mapCenter_str};
        
        var mapStartTime = times[0];
        var mapEndTime = times[times.length - 1];
        
        var map = L.map('map', {{
          center: mapCenter,
          zoom: {default_zoom},
          timeDimension: true,
          timeDimensionOptions: {{
            timeInterval: mapStartTime + "/" + mapEndTime,
            period: "PT1S",
            currentTime: new Date(mapStartTime).getTime()
          }}
        }});
        
        L.control.timeDimension({{
          autoPlay: true,
          loopButton: true,
          timeSliderDragUpdate: true,
          speedSlider: true,
          playerOptions: {{
            transitionTime: 100,
            loop: true,
            startOver: true
          }},
          minSpeed: 0.1,
          maxSpeed: 20,
          displayDate: true
        }}).addTo(map);
        
        /********************
         * Base layers
         ********************/
        var osmStandard = L.tileLayer('https://{{s}}.tile.openstreetmap.org/{{z}}/{{x}}/{{y}}.png', {{ 
          attribution: '© OpenStreetMap Contributors' 
        }});
        var swissColor = L.tileLayer(
          'https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.pixelkarte-farbe/default/current/3857/{{z}}/{{x}}/{{y}}.jpeg',
          {{ 
            attribution: '© swisstopo <img src="https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Switzerland.svg" style="height:16px; vertical-align:middle;" alt="Swiss Flag">' 
          }}
        );
        var swissTopo = L.tileLayer(
          'https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{{z}}/{{x}}/{{y}}.jpeg',
          {{ 
            attribution: '© swisstopo <img src="https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Switzerland.svg" style="height:16px; vertical-align:middle;" alt="Swiss Flag">' 
          }}
        );
        var cartoPositron = L.tileLayer(
          'https://{{s}}.basemaps.cartocdn.com/light_all/{{z}}/{{x}}/{{y}}{{r}}.png',
          {{ attribution: '© OpenStreetMap contributors, © CartoDB' }}
        );
        var cartoDark = L.tileLayer(
          'https://{{s}}.basemaps.cartocdn.com/dark_all/{{z}}/{{x}}/{{y}}{{r}}.png',
          {{ attribution: '© OpenStreetMap contributors, © CartoDB' }}
        );
        
        var baseLayers = {{
          "OSM Standard": osmStandard,
          "Swiss Color": swissColor,
          "Swiss Topo": swissTopo,
          "CartoDB Positron": cartoPositron,
          "CartoDB Dark Matter": cartoDark
        }};
        
        /********************
         * Overlay layers
         ********************/
        // FeatureGroup for drawings (Leaflet.draw) - now added by default
        var drawnItems = new L.FeatureGroup();
        drawnItems.addTo(map);
        
        // Animation layer 1: group all time-based image overlays
        var animationLayer = L.layerGroup();
        for (let i = 0; i < loadedUrls.length; i++) {{
          var overlay = L.imageOverlay(loadedUrls[i], imageBounds, {{ opacity: {overlay_opacity} }});
          var tdLayer = L.timeDimension.layer.imageOverlay(overlay, {{ time: times[i] }});
          animationLayer.addLayer(tdLayer);
        }}
        animationLayer.addTo(map);
        
        // Animation layer 2: identical to the first (for demonstration)
        var animationLayer2 = L.layerGroup();
        for (let i = 0; i < loadedUrls.length; i++) {{
          var overlay = L.imageOverlay(loadedUrls[i], imageBounds, {{ opacity: {overlay_opacity} }});
          var tdLayer = L.timeDimension.layer.imageOverlay(overlay, {{ time: times[i] }});
          animationLayer2.addLayer(tdLayer);
        }}
        
        // Layers control: base layers and overlays (with user-defined names)
        L.control.layers(baseLayers, {{
          "{animation_layer_name}": animationLayer,
          "{animation_layer2_name}": animationLayer2,
          "{drawings_layer_name}": drawnItems
        }}).addTo(map);
        
        /********************
         * Measure control
         ********************/
        var measureControl = new L.Control.Measure({{
          primaryLengthUnit: 'meters',
          primaryAreaUnit: 'hectares',
          position: 'topleft'
        }});
        measureControl.addTo(map);
        
        // Add one of the base layers by default
        swissTopo.addTo(map);
        
        /*************************************************
         * Leaflet.draw
         *************************************************/
        var drawControl = new L.Control.Draw({{
          edit: {{ featureGroup: drawnItems }},
          draw: {{
            polygon: true,
            polyline: true,
            rectangle: true,
            circle: true,
            marker: true
          }}
        }});
        map.addControl(drawControl);
        
        // --- New Control: Button to save drawings ---
        var saveDrawingsControl = L.Control.extend({{
          options: {{
            position: 'topleft'
          }},
          onAdd: function(map) {{
            var container = L.DomUtil.create('div', 'leaflet-bar leaflet-control');
            container.style.backgroundColor = 'white';
            container.style.padding = '10px';
            container.style.cursor = 'pointer';
            container.title = 'Save drawings';
            container.innerHTML = '<i class="fa fa-save"></i>';
            L.DomEvent.disableClickPropagation(container);
            L.DomEvent.on(container, 'click', function(e) {{
              // Convert the drawings layer to GeoJSON
              var data = drawnItems.toGeoJSON();
              var convertedData = JSON.stringify(data, null, 2);
              // Create a Blob and generate a URL for download
              var blob = new Blob([convertedData], {{ type: 'application/json' }});
              var url = URL.createObjectURL(blob);
              var a = document.createElement('a');
              a.href = url;
              a.download = 'drawings.geojson';
              document.body.appendChild(a);
              a.click();
              document.body.removeChild(a);
              URL.revokeObjectURL(url);
            }});
            return container;
          }}
        }});
        map.addControl(new saveDrawingsControl());
        // --- End of save control ---
        
        map.on('draw:created', function(e) {{
          var type = e.layerType,
              layer = e.layer;
          drawnItems.addLayer(layer);
          var infoText = "";
          if (type === 'polygon' || type === 'rectangle') {{
            var latlngs = layer.getLatLngs();
            if (Array.isArray(latlngs[0])) {{ latlngs = latlngs[0]; }}
            var area = L.GeometryUtil.geodesicArea(latlngs);
            var perimeter = 0;
            for (var j = 0; j < latlngs.length; j++) {{
              var next = latlngs[(j + 1) % latlngs.length];
              perimeter += latlngs[j].distanceTo(next);
            }}
            infoText = "Area: " + area.toFixed(2) + " m², Perimeter: " + perimeter.toFixed(2) + " m";
          }} else if (type === 'circle') {{
            var r = layer.getRadius();
            var area = Math.PI * r * r;
            var circumference = 2 * Math.PI * r;
            infoText = "Circle Area: " + area.toFixed(2) + " m², Circumference: " + circumference.toFixed(2) + " m";
          }} else if (type === 'polyline') {{
            var latlngs = layer.getLatLngs();
            var length = 0;
            for (var k = 0; k < latlngs.length - 1; k++) {{
              length += latlngs[k].distanceTo(latlngs[k+1]);
            }}
            infoText = "Length: " + length.toFixed(2) + " m";
          }} else if (type === 'marker') {{
            var latlng = layer.getLatLng();
            infoText = "Coordinates: " + latlng.lat.toFixed(5) + ", " + latlng.lng.toFixed(5);
          }}
          layer.bindPopup(infoText).openPopup();
        }});
      }});
    }});
  </script>
</body>
</html>
"""

# Finally, write the html_content to a file
with open(output_html_filename, "w", encoding="utf-8") as f:
    f.write(html_content)

print(f"HTML updated and exported to '{output_html_filename}'.")
# Out:
# HTML updated and exported to 'my_map.html'.

# %% [markdown]
# Original aquí abajo

# %% [markdown]
# ```python
# # -*- coding: utf-8 -*-
# """
# Código para ejecutar varios modelos de Iber en serie
#
# Gonzalo García-Alén Julio/2023
# """
#
# import os
# import sys
# import subprocess
#
# # Aquí indicamos la ruta de los modelos que queremos que sean ejecutados
# ModelosIber = [r'E:\te7.gid', r'E:\te8.gid']
#
# # Especificamos el ejecutable a usar, que ya debe estar en cada carpeta .gid
# # Todos los ejecutables de Iber están en esta ruta dentro de la carpeta donde
# # se ha instalado el programa: ...\Iber 3.3\problemtypes\IBER.gid\bin\windows
# iber_exe = r'C:\Program Files\Iber\Iber 3.3.1\problemtypes\IBER.gid\bin\windows\IberPlus.exe'  # 'Iber.exe', 'IberPlus.exe' o 'RIber.exe'
#
#
# print('\tEjecutando modelos Iber:')
# for i in range(len(ModelosIber)):
#     os.chdir(ModelosIber[i])
#     a = ('\t' + str(i+1) + '/' + str(len(ModelosIber)))
#     sys.stdout.write('\r'+a)
#     subprocess.call( iber_exe )
#     if i == (len(ModelosIber)-1): print('\n')
#     print('done')
# ```
