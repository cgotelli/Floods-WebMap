# %% [markdown]
# # Automatización Iber 3.3.1

# %% [markdown]
# ## Modificación del proyecto

# %% [markdown]
# Comenzamos con la modificación del modelo para el cambio automático de la condición de borde de entrada. Esto incluye la modificación de la CB, el remallado, la asignación de elevación para cada nodo

# %%
import pandas as pd
import os 
import sys
import subprocess
import os
import re
import os
import re
import numpy as np
import rasterio
from rasterio.transform import from_origin
from rasterio.io import MemoryFile
from rasterio.warp import calculate_default_transform, reproject, Resampling
from pyproj import Transformer
from PIL import Image, ImageDraw, ImageFont
import shutil
import os
import numpy as np
from PIL import Image, ImageDraw, ImageFont

# %%
main_folder = r"G:\Floods-WebMap"
# Definir el directorio del proyecto (ajustar según sea necesario)
model_directory = os.path.join(main_folder,"cruce_test.gid")

# Definir el archivo batch donde se guardarán los comandos
batch_file = os.path.join(mainf_folder,"instructions.bch")

hydrograph_file = os.path.join(main_folder, "hydrograph.csv")
hydrograph_file
# Out:
# 'G:\\Floods-WebMap\\hydrograph.csv'

# %%
# Función para escribir en el archivo batch
def write_to_batch(commands):
    with open(batch_file, "w") as f:
        for command in commands:
            f.write(command + "\n")

# 1. Cargar el archivo del proyecto
load_project_command = f"MEscape Files Read {{{model_directory}}}"

# 2. Modificar la condición de borde (función de generación del comando)
def load_hydrograph(file_path=hydrograph_file):
    try:
        df = pd.read_csv(file_path, header=None, sep=",")
        df.columns = ["Tiempo", "Caudal"]
        return df
    except Exception as e:
        print(f"Error al leer el archivo: {e}")
        return None

def generate_boundary_condition_command(face_number, df):
    if df is None or df.empty:
        return "Error: No se han cargado datos del hidrograma."
    
    hydrograph_str = " ".join([f"{row['Tiempo']} {row['Caudal']}" for _, row in df.iterrows()])
    
    command = f"Mescape Data Conditions AssignCond 2D_Inlet Change 0 {{0 0 0}} Total_Discharge Critical/Subcritical #N# 8 {hydrograph_str} #N# 3 0.0 0.0 0.0 1 _Subcritical #N# 2 0.0 0.0 Elevation #N# 3 0.0 0.0 0.0 #N# 3 0.0 0.0 0.0 #N# 2 0.0 0.0 #N# 1 0.0 {face_number} escape"
    
    return command

# Leer el hidrograma y generar el comando
df_hydrograph = load_hydrograph()
boundary_condition_command = generate_boundary_condition_command(2, df_hydrograph)  # Número de cara por defecto: 2

# 3. Generar la malla
meshing_commands = [
    "Mescape Meshing Generate Yes {-tcl- GiD_RaiseEvent GiD_Event_BeforeMeshGeneration 0.551582} escape",
    "Mescape Utilities SwapNormals Surfaces SelByNormal 1:end escape 0.0 0.0 1.0 Yes escape",
    "Mescape Meshing Generate 0.551582 MeshingParametersFrom=Preferences escape 'SetViewMode Mesh"
]

# Escribir los comandos en el archivo batch
all_commands = [load_project_command, boundary_condition_command] + meshing_commands
write_to_batch(all_commands)

print(f"Archivo batch '{batch_file}' generado con éxito en el directorio actual.")
# Out:
# Archivo batch 'G:/Floods-WebMap\instructions.bch' generado con éxito en el directorio actual.

# %% [markdown]
# ## Corriendo el proyecto
# Una vez creado el proyecto, en vez de correr el caso desde la consola batch, preferimos llamar al solver de IberPlus directamente. Así podremos hacer uso de CUDA para acelerar el cálculo.

# %%
# Ruta del ejecutable de Iber (ajústala según la instalación)
iber_exe = r'C:\Program Files\Iber\Iber 3.3.1\problemtypes\IBER.gid\bin\windows\IberPlus.exe'  

# Ruta del ejecutable de GiD
iber_gui_exe = r"C:\Program Files\Iber\Iber 3.3.1\gid.exe"

# Lista de modelos Iber a ejecutar (definida como lista por si se necesitan varios)
modelos_iber = [r'C:\temp\cruce_test.gid']  # Agregar más modelos si es necesario

print("\tEjecutando modelos Iber:")

for i, modelo in enumerate(modelos_iber, start=1):
    os.chdir(modelo)  # Cambia al directorio del modelo
    print(f"\r\tEjecutando {i}/{len(modelos_iber)}: {modelo}")

    # Llamar al ejecutable de Iber
    subprocess.call(iber_exe)

    print("\tModelo completado.")

print("\nTodos los modelos han sido ejecutados.")
# Out:
# 	Ejecutando modelos Iber:
# 	Ejecutando 1/1: C:\temp\cruce_test.gid
# 	Modelo completado.
#
# Todos los modelos han sido ejecutados.

# %% [markdown]
# ## Exportando a Raster
# Exportamos el resultado de la simulación como Raster y los renombramos.

# %%
# Definir el archivo batch para el postproceso
postprocess_batch_file = os.path.join(main_folder,"postprocess.bch")

# Crear el contenido del archivo batch para el postproceso
postprocess_commands = f"""MEscape Files Read {{{model_directory}}}
Mescape Postprocess escape
*****tcl set ::Reproject 0
*****tcl set ::Interpolation linear
*****tcl set ::cell 0.1
*****tcl set ::Timeresults Allsteps
*****tcl set ::PostRaster(thisanalysis) Hydraulic
*****tcl set ::PostRaster(thisstep) =
*****tcl set ::PostRaster(over) elements
*****tcl set ::PostRaster(thiszone) 1
*****tcl set ::PostRaster(thishemis) N
*****tcl set ::PostRaster(output,number) 1
*****tcl set "::PostRaster(output,Depth (m))" 1
*****tcl set ::PostRaster(output,Froude) 0
*****tcl set ::PostRaster(output,connectivities) 0
*****tcl set "::PostRaster(output,Water Elevation (m))" 0
*****tcl set "::PostRaster(output,Specific Discharge (m2/s))" 0
*****tcl set ::PostRaster(output,coordinates) 0
*****tcl set "::PostRaster(output,Velocity (m/s))" 1
*****tcl ::PostRaster::ApplyListEntities nada
MEscape Quit No
"""

# Guardar el archivo batch en la misma carpeta que el otro batch
with open(postprocess_batch_file, "w") as f:
    f.write(postprocess_commands)

print(f"Archivo batch '{postprocess_batch_file}' generado con éxito.")



# Comando para ejecutar el postproceso en Iber
command = [iber_gui_exe, "-b", os.path.abspath(postprocess_batch_file), "-n"]

# Ejecutar el postproceso
print("\nExportando rásters de los resultados.")
subprocess.run(command)

print("\nExportación ráster completada.")
# Out:
# Archivo batch 'G:\Floods-WebMap\postprocess.bch' generado con éxito.
#
# Exportando rásters de los resultados.
#
# Exportación ráster completada.

# %%
# Directorio donde se guardan los archivos ASC
asc_directory = os.path.join(model_directory, "Rasters","Hydraulic")

# Expresión regular para detectar archivos con formato Depth____X.X.asc o Depth____X.asc
pattern = re.compile(r"Depth____(\d+)(?:\.\d+)?\.asc")

# Renombrar archivos
for filename in os.listdir(asc_directory):
    match = pattern.match(filename)
    if match:
        original_number = int(float(match.group(1)))  # Convertir a entero eliminando decimales
        new_number = f"{original_number:06d}"  # Convertir a 6 cifras con ceros a la izquierda
        new_filename = f"Depth____{new_number}.asc"
        old_path = os.path.join(asc_directory, filename)
        new_path = os.path.join(asc_directory, new_filename)
        
        # Renombrar el archivo
        os.replace(old_path, new_path)
        # print(f"Renombrado: {filename} → {new_filename}")

print("\nTodos los archivos han sido renombrados correctamente.")
# Out:
# Todos los archivos han sido renombrados correctamente.

# %% [markdown]
# ## Conversión de ráster a imágenes

# %%
# ====================================================
# PARÁMETROS GLOBALES
# ====================================================

source_images_dir = os.path.join(asc_directory,"Processed")  # Carpeta donde se guardarán los PNGs
USER_MAX_DEPTH = 2.0  # Valor máximo de profundidad en metros
SRC_CRS = "EPSG:2056"  # CRS de origen (CH1903+ / LV95)
DST_CRS = "EPSG:3857"  # CRS de salida (Web Mercator)

# Crear la carpeta de salida si no existe
if not os.path.exists(source_images_dir):
    os.makedirs(source_images_dir)

# ====================================================
# FUNCIÓN PARA LEER ARCHIVOS ASC
# ====================================================

def read_ascii_xllcenter(filename):
    """Lee un archivo ASC y extrae sus datos y metadatos."""
    with open(filename, 'r') as f:
        header_lines = [next(f) for _ in range(6)]
    
    ncols = nrows = None
    xllcenter = yllcenter = None
    cellsize = None
    nodata_val = None

    for line in header_lines:
        parts = re.split(r"\s+", line.strip())
        key = parts[0].upper()
        val = float(parts[-1])
        if key.startswith("NCOLS"):
            ncols = int(val)
        elif key.startswith("NROWS"):
            nrows = int(val)
        elif key.startswith("XLLCENTER"):
            xllcenter = val
        elif key.startswith("YLLCENTER"):
            yllcenter = val
        elif key.startswith("CELLSIZE"):
            cellsize = val
        elif key.startswith("NODATA_VALUE"):
            nodata_val = val

    data = np.loadtxt(filename, skiprows=6)
    x_min = xllcenter - 0.5 * cellsize
    y_max = yllcenter + (nrows - 0.5) * cellsize
    transform = from_origin(x_min, y_max, cellsize, cellsize)
    return data, transform, ncols, nrows, nodata_val

# ====================================================
# FUNCIÓN PARA CONVERTIR ASC A PNG
# ====================================================

def asc_to_png(filename_asc, output_png):
    """Convierte un archivo ASC en una imagen PNG con una rampa de colores."""
    data, transform, width, height, nodata_val = read_ascii_xllcenter(filename_asc)
    
    low_rgb = np.array([173, 216, 230], dtype=np.float32)  # Azul claro
    high_rgb = np.array([0, 0, 139], dtype=np.float32)      # Azul oscuro
    limit_val = 0.99 * USER_MAX_DEPTH

    band = data
    valid_mask = band != nodata_val
    scaled = ((band - 0) / (limit_val - 0)) * 255.0
    scaled = np.clip(scaled, 0, 255).astype(np.float32)

    R = low_rgb[0] + (high_rgb[0] - low_rgb[0]) * (scaled / 255.0)
    G = low_rgb[1] + (high_rgb[1] - low_rgb[1]) * (scaled / 255.0)
    B = low_rgb[2] + (high_rgb[2] - low_rgb[2]) * (scaled / 255.0)

    R = np.clip(R, 0, 255).astype(np.uint8)
    G = np.clip(G, 0, 255).astype(np.uint8)
    B = np.clip(B, 0, 255).astype(np.uint8)
    A = np.where(valid_mask, 255, 0).astype(np.uint8)

    img = np.dstack([R, G, B, A])
    Image.fromarray(img).save(output_png)

# ====================================================
# FUNCIÓN PARA RENOMBRAR LOS ARCHIVOS ASC
# ====================================================

def format_filename(filename):
    """Renombra archivos ASC a PNG con 6 cifras en el nombre."""
    match = re.search(r"Depth____(\d+)\.asc", filename)
    if match:
        num = int(match.group(1))
        formatted_num = f"{num:06d}"
        return f"Depth_{formatted_num}.png"
    return None

def extract_number(filename):
    """Extrae el número de tiempo de los archivos ASC."""
    match = re.search(r"Depth____(\d+)\.asc", filename)
    return int(match.group(1)) if match else float('inf')

# ====================================================
# PROCESAMIENTO DE ARCHIVOS
# ====================================================

# Listar archivos ASC y ordenarlos por tiempo
asc_files = [f for f in os.listdir(asc_directory) if f.startswith("Depth____") and f.endswith(".asc")]
asc_files = sorted(asc_files, key=extract_number)

print(f"Se encontraron {len(asc_files)} archivos ASC para procesar.")

for filename in asc_files:
    input_path = os.path.join(asc_directory, filename)
    output_name = format_filename(filename)  # Ejemplo: Depth_000123.png

    if output_name is not None:
        output_path = os.path.join(source_images_dir, output_name)
        asc_to_png(input_path, output_path)
        # print(f"{filename} → {output_name}")

print("\nProceso completado. Archivos PNG generados en:", source_images_dir)
# Out:
# Se encontraron 351 archivos ASC para procesar.
#
# Proceso completado. Archivos PNG generados en: G:\Floods-WebMap\cruce_test.gid\Rasters\Hydraulic\Processed

# %% [markdown]
# ## Instalación Git (opcional)

# %% [markdown]
# Si no está instalado Git:

# %% [markdown]
# ```raw
# !conda install -c conda-forge git -y
#
#
# !git --version
#
#
# !git config --global user.name "cgotelli"
# !git config --global user.email "clemente.gotelli@outlook.com"
#
#
# !git config --global --list
# ```

# %% [markdown]
# Una vez listo eso, clonamos:

# %% [markdown]
# ```raw
# !git clone https://github.com/cgotelli/Floods-WebMap.git G:/Floods-WebMap
# ```

# %% [markdown]
# ## Subiendo archivos a Github

# %%
# Directorios en 
local_repo_dir = r"G:\Floods-WebMap"  # Directorio del repo clonado localmente

# Directorios de destino en el repositorio en G:
target_png_dir = os.path.join(local_repo_dir, "simulation_files", "png")
target_asc_dir = os.path.join(local_repo_dir, "simulation_files", "asc")
target_aux_dir = os.path.join(local_repo_dir, "aux_images")  # Carpeta para la leyenda

# Parámetros de la leyenda
LEGEND_WIDTH = 50
LEGEND_HEIGHT = 256
TOP_MARGIN = 40
BOTTOM_MARGIN = 20
LEFT_MARGIN = 25
RIGHT_MARGIN = 10
USER_MAX_DEPTH = 2.0  # Máxima profundidad a considerar en la leyenda

# %%
# Función para limpiar carpetas antes de copiar nuevos archivos (excepto aux_images)
def clean_directory(directory):
    if os.path.exists(directory):
        for file in os.listdir(directory):
            file_path = os.path.join(directory, file)
            try:
                os.remove(file_path)
                # print(f"🗑️ Eliminado: {file}")
            except Exception as e:
                print(f"⚠️ Error al eliminar {file}: {e}")
    else:
        os.makedirs(directory)

# Limpiar carpetas PNG y ASC antes de copiar nuevos archivos (NO TOCAR aux_images)
print("🧹 Eliminando archivos anteriores en G:/Floods-WebMap/simulation_files/png...")
clean_directory(target_png_dir)

print("🧹 Eliminando archivos anteriores en G:/Floods-WebMap/simulation_files/asc...")
clean_directory(target_asc_dir)

# Función para copiar archivos
def copy_files(source_dir, target_dir, extension):
    for file in os.listdir(source_dir):
        if file.endswith(extension):
            shutil.copy2(os.path.join(source_dir, file), os.path.join(target_dir, file))
            # print(f"📂 Copiado: {file}")

# Copiar nuevos archivos PNG
print("\n📤 Copiando nuevos archivos PNG...")
copy_files(source_images_dir, target_png_dir, ".png")

# Copiar nuevos archivos ASC
print("\n📤 Copiando nuevos archivos ASC...")
copy_files(asc_directory, target_asc_dir, ".asc")

# ====================================================
# Generar la imagen de la leyenda (SIN ELIMINAR ARCHIVOS ANTERIORES EN aux_images)
# ====================================================

print("\n🎨 Generando la leyenda...")

# Crear imagen RGBA para la leyenda
legend_array = np.ones((LEGEND_HEIGHT, LEGEND_WIDTH, 4), dtype=np.uint8) * 255
legend_array[..., 3] = 128  # Fondo con 50% de opacidad

# Gradiente de color (azul claro a azul oscuro)
low_rgb = np.array([173, 216, 230], dtype=np.float32)  # Azul claro
high_rgb = np.array([0, 0, 139], dtype=np.float32)  # Azul oscuro
limit_val = 0.9 * USER_MAX_DEPTH

inner_height = LEGEND_HEIGHT - TOP_MARGIN - BOTTOM_MARGIN
for y in range(inner_height):
    factor = y / float(inner_height - 1)
    inv_factor = 1 - factor  # Invertir para que la parte superior sea azul oscuro
    color = low_rgb + (high_rgb - low_rgb) * inv_factor
    color = np.clip(color, 0, 255).astype(np.uint8)
    for x in range(LEFT_MARGIN, LEGEND_WIDTH - RIGHT_MARGIN):
        legend_array[TOP_MARGIN + y, x, :3] = color
        legend_array[TOP_MARGIN + y, x, 3] = 255  # Opaque en la barra de color

# Convertir a imagen
legend_img = Image.fromarray(legend_array, mode="RGBA")
draw = ImageDraw.Draw(legend_img)
font = ImageFont.load_default()

# Etiquetas
title_text = "Depth [m]"
draw.text(((LEGEND_WIDTH - draw.textlength(title_text, font)) // 2, 2), title_text, font=font, fill=(0, 0, 0, 255))

# Min label (0)
draw.text((LEFT_MARGIN - 10, LEGEND_HEIGHT - BOTTOM_MARGIN), "0", font=font, fill=(0, 0, 0, 255))

# Max label (90% de USER_MAX_DEPTH)
max_label = f"{limit_val:.1f}"
draw.text((LEFT_MARGIN - 10, TOP_MARGIN - 10), max_label, font=font, fill=(0, 0, 0, 255))

# Guardar la leyenda en G:\Floods-WebMap\aux_images (NO SE ELIMINAN ARCHIVOS ANTERIORES)
legend_output = os.path.join(target_aux_dir, "legend.png")
legend_img.save(legend_output)
print(f"✅ Leyenda guardada en {legend_output}")

print("\n✅ Todos los archivos han sido copiados en G:/Floods-WebMap.")

# %%
cd G:/Floods-WebMap
# Out:
# G:\Floods-WebMap

# %% [markdown]
# Pushing the changes to Github

# %%
# !git add simulation_files/png
# !git add simulation_files/asc
# !git add aux_images/legend.png
# !git commit -m "Actualización de imágenes PNG, archivos ASC y leyenda en aux_images (sin eliminar previos)"
# !git push origin main

# %% [markdown]
# ## Building the HTML Web Map

# %%
output_html_filename = "my_map.html"

# User-defined variables for customization:
html_title = "My Custom Map Title"           # Title of the HTML page
animation_layer_name = "Animation Layer 1"    # Name for the first animation layer
animation_layer2_name = "Animation Layer 2"   # Name for the second animation layer
drawings_layer_name = "Drawings Layer"        # Name for the drawings layer

# Define the GitHub folder URL (the one seen in the browser)
github_url = "https://github.com/cgotelli/Floods-WebMap/tree/main/simulation_files/png"

# Legend image location in the new repo:
legend_url = "https://github.com/cgotelli/Floods-WebMap/raw/refs/heads/main/aux_images/legend.png"

default_zoom = 15
overlay_opacity = 0.75
start_year = 2025
start_month = 1
start_day = 1

# %%
# Convert the GitHub URL to the corresponding API URL.
# GitHub URL format:
#   https://github.com/{user}/{repo}/tree/{branch}/{path}
# API URL format:
#   https://api.github.com/repos/{user}/{repo}/contents/{path}
if "github.com" in github_url:
    # Remove the "https://github.com/" prefix.
    path_part = github_url.replace("https://github.com/", "")
    # Split the remaining part.
    parts = path_part.split("/")
    # Expecting parts to be: [user, repo, "tree", branch, path...]
    if len(parts) >= 5 and parts[2] == "tree":
        user = parts[0]
        repo = parts[1]
        branch = parts[3]  # branch is not used in API URL
        folder_path = "/".join(parts[4:])
        folder_url = f"https://api.github.com/repos/{user}/{repo}/contents/{folder_path}"
    else:
        # Fallback to the provided URL if the format is unexpected
        folder_url = github_url
else:
    folder_url = github_url

# Suppose we've computed bounding_boxes from the ASC->PNG script.
# We'll use the first bounding box for demonstration:
if 'bounding_boxes' in globals() and bounding_boxes:
    # bounding_boxes[i] => (output_png_name, (lat_bottom, lon_left, lat_top, lon_right))
    _, (lat_bottom, lon_left, lat_top, lon_right) = bounding_boxes[0]
else:
    # Fallback or default values
    lat_bottom, lon_left, lat_top, lon_right = 46.5199, 6.6309, 46.5211, 6.6363

# Build the JavaScript strings for the Leaflet bounds and center.
imageBounds_str = f"[[{lat_bottom}, {lon_left}], [{lat_top}, {lon_right}]]"
center_lat = 0.5 * (lat_bottom + lat_top)
center_lon = 0.5 * (lon_left + lon_right)
mapCenter_str = f"[{center_lat:.5f}, {center_lon:.5f}]"

# Start date for frames (JS-compatible)
startDateJS = f"new Date('{start_year:04d}-{start_month:02d}-{start_day:02d}T00:00:00Z')"

# Build the HTML content with all text in English and customized title and layer names.
html_content = f"""<!DOCTYPE html>
<html>
<head>
  <title>{html_title}</title>
  <meta charset="utf-8"/>
  <!-- CSS: Leaflet -->
  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.5.1/dist/leaflet.css" />
  <!-- CSS: Leaflet TimeDimension -->
  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.min.css" />
  <!-- CSS: Leaflet Measure -->
  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet-measure@3.1.0/dist/leaflet-measure.min.css">
  <!-- CSS: Leaflet.draw (v0.4.2) -->
  <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/0.4.2/leaflet.draw.css"/>
  <!-- CSS: FontAwesome for icons -->
  <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">
  <style>
    #map {{
      position: relative;
      width: 100%;
      height: 600px;
    }}
  </style>
</head>
<body>
  <div id="map">
    <!-- Legend in the lower-right corner -->
    <div id="legend" style="position: absolute; bottom: 15px; right: 10px; background: rgba(255,255,255,0); padding: 5px; border: 0px solid #ccc; z-index: 1000;">
      <img src="{legend_url}" alt="Depth Legend">
    </div>
  </div>
  
  <!-- JS: Leaflet, Iso8601, TimeDimension, Measure, Leaflet.draw -->
  <script src="https://cdn.jsdelivr.net/npm/leaflet@1.5.1/dist/leaflet.js"></script>
  <script src="https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js"></script>
  <script src="https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js"></script>
  <script src="https://cdn.jsdelivr.net/npm/leaflet-measure@3.1.0/dist/leaflet-measure.min.js"></script>
  <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/0.4.2/leaflet.draw.js"></script>
  
  <script>
    /*************************************************
     * preloadImages: loads all image URLs in parallel
     *************************************************/
    function preloadImages(urls, callback) {{
      let loadedCount = 0;
      const total = urls.length;
      urls.forEach(url => {{
        const img = new Image();
        img.onload = img.onerror = function() {{
          loadedCount++;
          if (loadedCount === total) {{
            callback(urls);
          }}
        }};
        img.src = url;
      }});
    }}
    
    /*************************************************
     * getPNGFilesFromGitHubFolder: fetch Depth_*.png from new repo
     *************************************************/
    function getPNGFilesFromGitHubFolder(folderUrl, callback) {{
      fetch(folderUrl)
        .then(response => response.json())
        .then(json => {{
          let pngFiles = json.filter(item => 
            item.type === "file" && item.name.toLowerCase().startsWith("depth")
          ).map(item => item.download_url);
          pngFiles.sort();
          callback(pngFiles);
        }})
        .catch(error => {{
          console.error("Error fetching GitHub folder:", error);
          callback([]);
        }});
    }}
    
    /*************************************************
     * Subclass for ImageOverlay in TimeDimension
     *************************************************/
    L.TimeDimension.Layer.ImageOverlay = L.TimeDimension.Layer.extend({{
      initialize: function(layer, options) {{
        L.TimeDimension.Layer.prototype.initialize.call(this, layer, options);
        if (typeof this.options.time === 'string') {{
          this._time = new Date(this.options.time).getTime();
        }} else if (this.options.time instanceof Date) {{
          this._time = this.options.time.getTime();
        }} else {{
          this._time = this.options.time;
        }}
      }},
      _onNewTimeLoading: function(ev) {{
        this.fire('timeload', {{ time: ev.time }});
      }},
      isReady: function(time) {{
        return true;
      }},
      _update: function() {{
        if (!this._map) return;
        var currentTime = this._timeDimension.getCurrentTime();
        var tolerance = 500;
        console.log("Overlay time: " + this._time + ", currentTime: " + currentTime);
        if (Math.abs(currentTime - this._time) < tolerance) {{
          if (!this._map.hasLayer(this._baseLayer)) {{
            console.log("Adding overlay for time " + this._time);
            this._map.addLayer(this._baseLayer);
          }}
        }} else {{
          if (this._map.hasLayer(this._baseLayer)) {{
            console.log("Removing overlay for time " + this._time);
            this._map.removeLayer(this._baseLayer);
          }}
        }}
        return true;
      }}
    }});
    L.timeDimension.layer.imageOverlay = function(layer, options) {{
      return new L.TimeDimension.Layer.ImageOverlay(layer, options);
    }};
    
    /*************************************************
     * Initialization
     *************************************************/
    var folderUrl = "{folder_url}";
    
    getPNGFilesFromGitHubFolder(folderUrl, function(pngFiles) {{
      console.log("Obtained PNG URLs:", pngFiles);
      
      preloadImages(pngFiles, function(loadedUrls) {{
        console.log("All images have been preloaded.");
        
        var times = [];
        var startTime = {startDateJS};
        for (var i = 0; i < loadedUrls.length; i++) {{
          var time = new Date(startTime.getTime() + i * 1000);
          times.push(time.toISOString());
        }}
        
        var imageBounds = {imageBounds_str};
        var mapCenter = {mapCenter_str};
        
        var mapStartTime = times[0];
        var mapEndTime = times[times.length - 1];
        
        var map = L.map('map', {{
          center: mapCenter,
          zoom: {default_zoom},
          timeDimension: true,
          timeDimensionOptions: {{
            timeInterval: mapStartTime + "/" + mapEndTime,
            period: "PT1S",
            currentTime: new Date(mapStartTime).getTime()
          }}
        }});
        
        L.control.timeDimension({{
          autoPlay: true,
          loopButton: true,
          timeSliderDragUpdate: true,
          speedSlider: true,
          playerOptions: {{
            transitionTime: 100,
            loop: true,
            startOver: true
          }},
          minSpeed: 0.1,
          maxSpeed: 20,
          displayDate: true
        }}).addTo(map);
        
        /********************
         * Base layers
         ********************/
        var osmStandard = L.tileLayer('https://{{s}}.tile.openstreetmap.org/{{z}}/{{x}}/{{y}}.png', {{ 
          attribution: '© OpenStreetMap Contributors' 
        }});
        var swissColor = L.tileLayer(
          'https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.pixelkarte-farbe/default/current/3857/{{z}}/{{x}}/{{y}}.jpeg',
          {{ 
            attribution: '© swisstopo <img src="https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Switzerland.svg" style="height:16px; vertical-align:middle;" alt="Swiss Flag">' 
          }}
        );
        var swissTopo = L.tileLayer(
          'https://wmts.geo.admin.ch/1.0.0/ch.swisstopo.swissimage/default/current/3857/{{z}}/{{x}}/{{y}}.jpeg',
          {{ 
            attribution: '© swisstopo <img src="https://upload.wikimedia.org/wikipedia/commons/f/f3/Flag_of_Switzerland.svg" style="height:16px; vertical-align:middle;" alt="Swiss Flag">' 
          }}
        );
        var cartoPositron = L.tileLayer(
          'https://{{s}}.basemaps.cartocdn.com/light_all/{{z}}/{{x}}/{{y}}{{r}}.png',
          {{ attribution: '© OpenStreetMap contributors, © CartoDB' }}
        );
        var cartoDark = L.tileLayer(
          'https://{{s}}.basemaps.cartocdn.com/dark_all/{{z}}/{{x}}/{{y}}{{r}}.png',
          {{ attribution: '© OpenStreetMap contributors, © CartoDB' }}
        );
        
        var baseLayers = {{
          "OSM Standard": osmStandard,
          "Swiss Color": swissColor,
          "Swiss Topo": swissTopo,
          "CartoDB Positron": cartoPositron,
          "CartoDB Dark Matter": cartoDark
        }};
        
        /********************
         * Overlay layers
         ********************/
        // FeatureGroup for drawings (Leaflet.draw) - now added by default
        var drawnItems = new L.FeatureGroup();
        drawnItems.addTo(map);
        
        // Animation layer 1: group all time-based image overlays
        var animationLayer = L.layerGroup();
        for (let i = 0; i < loadedUrls.length; i++) {{
          var overlay = L.imageOverlay(loadedUrls[i], imageBounds, {{ opacity: {overlay_opacity} }});
          var tdLayer = L.timeDimension.layer.imageOverlay(overlay, {{ time: times[i] }});
          animationLayer.addLayer(tdLayer);
        }}
        animationLayer.addTo(map);
        
        // Animation layer 2: identical to the first (for demonstration)
        var animationLayer2 = L.layerGroup();
        for (let i = 0; i < loadedUrls.length; i++) {{
          var overlay = L.imageOverlay(loadedUrls[i], imageBounds, {{ opacity: {overlay_opacity} }});
          var tdLayer = L.timeDimension.layer.imageOverlay(overlay, {{ time: times[i] }});
          animationLayer2.addLayer(tdLayer);
        }}
        
        // Layers control: base layers and overlays (with user-defined names)
        L.control.layers(baseLayers, {{
          "{animation_layer_name}": animationLayer,
          "{animation_layer2_name}": animationLayer2,
          "{drawings_layer_name}": drawnItems
        }}).addTo(map);
        
        /********************
         * Measure control
         ********************/
        var measureControl = new L.Control.Measure({{
          primaryLengthUnit: 'meters',
          primaryAreaUnit: 'hectares',
          position: 'topleft'
        }});
        measureControl.addTo(map);
        
        // Add one of the base layers by default
        swissTopo.addTo(map);
        
        /*************************************************
         * Leaflet.draw
         *************************************************/
        var drawControl = new L.Control.Draw({{
          edit: {{ featureGroup: drawnItems }},
          draw: {{
            polygon: true,
            polyline: true,
            rectangle: true,
            circle: true,
            marker: true
          }}
        }});
        map.addControl(drawControl);
        
        // --- New Control: Button to save drawings ---
        var saveDrawingsControl = L.Control.extend({{
          options: {{
            position: 'topleft'
          }},
          onAdd: function(map) {{
            var container = L.DomUtil.create('div', 'leaflet-bar leaflet-control');
            container.style.backgroundColor = 'white';
            container.style.padding = '10px';
            container.style.cursor = 'pointer';
            container.title = 'Save drawings';
            container.innerHTML = '<i class="fa fa-save"></i>';
            L.DomEvent.disableClickPropagation(container);
            L.DomEvent.on(container, 'click', function(e) {{
              // Convert the drawings layer to GeoJSON
              var data = drawnItems.toGeoJSON();
              var convertedData = JSON.stringify(data, null, 2);
              // Create a Blob and generate a URL for download
              var blob = new Blob([convertedData], {{ type: 'application/json' }});
              var url = URL.createObjectURL(blob);
              var a = document.createElement('a');
              a.href = url;
              a.download = 'drawings.geojson';
              document.body.appendChild(a);
              a.click();
              document.body.removeChild(a);
              URL.revokeObjectURL(url);
            }});
            return container;
          }}
        }});
        map.addControl(new saveDrawingsControl());
        // --- End of save control ---
        
        map.on('draw:created', function(e) {{
          var type = e.layerType,
              layer = e.layer;
          drawnItems.addLayer(layer);
          var infoText = "";
          if (type === 'polygon' || type === 'rectangle') {{
            var latlngs = layer.getLatLngs();
            if (Array.isArray(latlngs[0])) {{ latlngs = latlngs[0]; }}
            var area = L.GeometryUtil.geodesicArea(latlngs);
            var perimeter = 0;
            for (var j = 0; j < latlngs.length; j++) {{
              var next = latlngs[(j + 1) % latlngs.length];
              perimeter += latlngs[j].distanceTo(next);
            }}
            infoText = "Area: " + area.toFixed(2) + " m², Perimeter: " + perimeter.toFixed(2) + " m";
          }} else if (type === 'circle') {{
            var r = layer.getRadius();
            var area = Math.PI * r * r;
            var circumference = 2 * Math.PI * r;
            infoText = "Circle Area: " + area.toFixed(2) + " m², Circumference: " + circumference.toFixed(2) + " m";
          }} else if (type === 'polyline') {{
            var latlngs = layer.getLatLngs();
            var length = 0;
            for (var k = 0; k < latlngs.length - 1; k++) {{
              length += latlngs[k].distanceTo(latlngs[k+1]);
            }}
            infoText = "Length: " + length.toFixed(2) + " m";
          }} else if (type === 'marker') {{
            var latlng = layer.getLatLng();
            infoText = "Coordinates: " + latlng.lat.toFixed(5) + ", " + latlng.lng.toFixed(5);
          }}
          layer.bindPopup(infoText).openPopup();
        }});
      }});
    }});
  </script>
</body>
</html>
"""

# Finally, write the html_content to a file
with open(output_html_filename, "w", encoding="utf-8") as f:
    f.write(html_content)

print(f"HTML updated and exported to '{output_html_filename}'.")

# %% [markdown]
# Pushamos hacia Github la nueva página.

# %%
# %cd G:\Floods-WebMap
# !git add -A
# !git commit -m "update HTML"
# !git push origin main
# Out:
# G:\Floods-WebMap
# [main 732fb1a] update HTML
#  2200 files changed, 175763 insertions(+)
#  create mode 100644 cruce_test.gid/ASCII/maxims.rep
#  create mode 100644 cruce_test.gid/Conexions.rep
#  create mode 100644 cruce_test.gid/Iber1D.dat
#  create mode 100644 cruce_test.gid/Iber2D.dat
#  create mode 100644 cruce_test.gid/Iber_AH.dat
#  create mode 100644 cruce_test.gid/Iber_AH_c.dat
#  create mode 100644 cruce_test.gid/Iber_AH_subs.dat
#  create mode 100644 cruce_test.gid/Iber_AtmosphericLoc.dat
#  create mode 100644 cruce_test.gid/Iber_AtmosphericVars.dat
#  create mode 100644 cruce_test.gid/Iber_Aval.dat
#  create mode 100644 cruce_test.gid/Iber_Bedload.dat
#  create mode 100644 cruce_test.gid/Iber_Bedload1D.dat
#  create mode 100644 cruce_test.gid/Iber_Bedmixtures.dat
#  create mode 100644 cruce_test.gid/Iber_Bedmixturesprop.dat
#  create mode 100644 cruce_test.gid/Iber_Breach.dat
#  create mode 100644 cruce_test.gid/Iber_CPUSolver.dat
#  create mode 100644 cruce_test.gid/Iber_Coliforms.dat
#  create mode 100644 cruce_test.gid/Iber_Culverts.dat
#  create mode 100644 cruce_test.gid/Iber_DBO.dat
#  create mode 100644 cruce_test.gid/Iber_DiffuR.dat
#  create mode 100644 cruce_test.gid/Iber_Discharges.dat
#  create mode 100644 cruce_test.gid/Iber_DischargesWQ.dat
#  create mode 100644 cruce_test.gid/Iber_Encroachment.dat
#  create mode 100644 cruce_test.gid/Iber_FloodDamage.dat
#  create mode 100644 cruce_test.gid/Iber_FloodDamageCurves.dat
#  create mode 100644 cruce_test.gid/Iber_Fosforo.dat
#  create mode 100644 cruce_test.gid/Iber_Gauges.dat
#  create mode 100644 cruce_test.gid/Iber_Groundwater.dat
#  create mode 100644 cruce_test.gid/Iber_H_IC.dat
#  create mode 100644 cruce_test.gid/Iber_Hazard.dat
#  create mode 100644 cruce_test.gid/Iber_Hyetograph.dat
#  create mode 100644 cruce_test.gid/Iber_Imbornales.dat
#  create mode 100644 cruce_test.gid/Iber_Internal_cond.dat
#  create mode 100644 cruce_test.gid/Iber_Junctions.dat
#  create mode 100644 cruce_test.gid/Iber_Losses.dat
#  create mode 100644 cruce_test.gid/Iber_Metal.dat
#  create mode 100644 cruce_test.gid/Iber_Nitro.dat
#  create mode 100644 cruce_test.gid/Iber_OD.dat
#  create mode 100644 cruce_test.gid/Iber_PH.dat
#  create mode 100644 cruce_test.gid/Iber_Phyto.dat
#  create mode 100644 cruce_test.gid/Iber_Pipes.dat
#  create mode 100644 cruce_test.gid/Iber_Pollutants.dat
#  create mode 100644 cruce_test.gid/Iber_Problemdata.dat
#  create mode 100644 cruce_test.gid/Iber_Rain.dat
#  create mode 100644 cruce_test.gid/Iber_RatingcurveQ.dat
#  create mode 100644 cruce_test.gid/Iber_Ratingcurves.dat
#  create mode 100644 cruce_test.gid/Iber_Results.dat
#  create mode 100644 cruce_test.gid/Iber_Roof.dat
#  create mode 100644 cruce_test.gid/Iber_SWMM.dat
#  create mode 100644 cruce_test.gid/Iber_SWMM_greenroof.dat
#  create mode 100644 cruce_test.gid/Iber_SWMM_roof.dat
#  create mode 100644 cruce_test.gid/Iber_Salinity.dat
#  create mode 100644 cruce_test.gid/Iber_SedMix.dat
#  create mode 100644 cruce_test.gid/Iber_SedMix_BC.dat
#  create mode 100644 cruce_test.gid/Iber_SedMix_ErodibleZones.dat
#  create mode 100644 cruce_test.gid/Iber_SedMix_IniCond.dat
#  create mode 100644 cruce_test.gid/Iber_SedMix_QsB.dat
#  create mode 100644 cruce_test.gid/Iber_SedimentRelation.dat
#  create mode 100644 cruce_test.gid/Iber_Sink&Sources.dat
#  create mode 100644 cruce_test.gid/Iber_SoilWaterBalance.dat
#  create mode 100644 cruce_test.gid/Iber_Susp_sed.dat
#  create mode 100644 cruce_test.gid/Iber_Temperature.dat
#  create mode 100644 cruce_test.gid/Iber_Turbulence.dat
#  create mode 100644 cruce_test.gid/Iber_UD_Param.dat
#  create mode 100644 cruce_test.gid/Iber_Variable_n.dat
#  create mode 100644 cruce_test.gid/Iber_Wind.dat
#  create mode 100644 cruce_test.gid/Iber_Wood.dat
#  create mode 100644 cruce_test.gid/Iber_WoodPr.dat
#  create mode 100644 cruce_test.gid/Iber_Woodgage.dat
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000000.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000001.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000002.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000003.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000004.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000005.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000006.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000007.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000008.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000009.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000010.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000011.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000012.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000013.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000014.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000015.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000016.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000017.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000018.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000019.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000020.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000021.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000022.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000023.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000024.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000025.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000026.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000027.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000028.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000029.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000030.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000031.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000032.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000033.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000034.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000035.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000036.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000037.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000038.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000039.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000040.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000041.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000042.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000043.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000044.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000045.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000046.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000047.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000048.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000049.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000050.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000051.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000052.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000053.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000054.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000055.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000056.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000057.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000058.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000059.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000060.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000061.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000062.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000063.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000064.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000065.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000066.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000067.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000068.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000069.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000070.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000071.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000072.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000073.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000074.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000075.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000076.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000077.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000078.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000079.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000080.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000081.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000082.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000083.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000084.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000085.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000086.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000087.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000088.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000089.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000090.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000091.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000092.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000093.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000094.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000095.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000096.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000097.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000098.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000099.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000100.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000101.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000102.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000103.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000104.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000105.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000106.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000107.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000108.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000109.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000110.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000111.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000112.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000113.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000114.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000115.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000116.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000117.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000118.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000119.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000120.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000121.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000122.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000123.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000124.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000125.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000126.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000127.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000128.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000129.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000130.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000131.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000132.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000133.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000134.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000135.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000136.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000137.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000138.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000139.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000140.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000141.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000142.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000143.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000144.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000145.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000146.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000147.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000148.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000149.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000150.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000151.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000152.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000153.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000154.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000155.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000156.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000157.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000158.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000159.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000160.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000161.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000162.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000163.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000164.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000165.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000166.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000167.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000168.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000169.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000170.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000171.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000172.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000173.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000174.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000175.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000176.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000177.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000178.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000179.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000180.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000181.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000182.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000183.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000184.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000185.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000186.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000187.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000188.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000189.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000190.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000191.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000192.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000193.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000194.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000195.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000196.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000197.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000198.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000199.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000200.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000201.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000202.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000203.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000204.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000205.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000206.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000207.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000208.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000209.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000210.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000211.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000212.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000213.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000214.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000215.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000216.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000217.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000218.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000219.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000220.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000221.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000222.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000223.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000224.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000225.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000226.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000227.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000228.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000229.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000230.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000231.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000232.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000233.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000234.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000235.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000236.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000237.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000238.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000239.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000240.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000241.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000242.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000243.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000244.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000245.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000246.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000247.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000248.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000249.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000250.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000251.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000252.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000253.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000254.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000255.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000256.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000257.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000258.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000259.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000260.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000261.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000262.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000263.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000264.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000265.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000266.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000267.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000268.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000269.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000270.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000271.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000272.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000273.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000274.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000275.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000276.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000277.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000278.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000279.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000280.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000281.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000282.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000283.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000284.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000285.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000286.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000287.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000288.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000289.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000290.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000291.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000292.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000293.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000294.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000295.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000296.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000297.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000298.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000299.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000300.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000301.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000302.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000303.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000304.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000305.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000306.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000307.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000308.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000309.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000310.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000311.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000312.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000313.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000314.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000315.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000316.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000317.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000318.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000319.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000320.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000321.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000322.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000323.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000324.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000325.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000326.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000327.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000328.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000329.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000330.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000331.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000332.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000333.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000334.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000335.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000336.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000337.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000338.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000339.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000340.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000341.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000342.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000343.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000344.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000345.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000346.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000347.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000348.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000349.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Depth____000350.asc
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000000.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000001.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000002.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000003.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000004.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000005.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000006.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000007.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000008.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000009.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000010.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000011.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000012.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000013.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000014.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000015.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000016.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000017.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000018.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000019.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000020.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000021.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000022.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000023.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000024.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000025.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000026.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000027.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000028.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000029.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000030.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000031.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000032.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000033.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000034.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000035.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000036.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000037.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000038.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000039.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000040.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000041.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000042.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000043.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000044.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000045.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000046.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000047.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000048.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000049.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000050.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000051.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000052.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000053.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000054.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000055.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000056.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000057.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000058.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000059.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000060.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000061.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000062.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000063.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000064.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000065.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000066.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000067.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000068.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000069.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000070.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000071.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000072.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000073.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000074.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000075.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000076.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000077.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000078.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000079.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000080.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000081.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000082.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000083.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000084.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000085.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000086.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000087.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000088.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000089.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000090.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000091.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000092.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000093.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000094.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000095.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000096.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000097.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000098.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000099.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000100.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000101.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000102.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000103.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000104.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000105.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000106.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000107.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000108.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000109.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000110.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000111.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000112.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000113.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000114.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000115.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000116.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000117.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000118.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000119.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000120.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000121.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000122.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000123.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000124.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000125.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000126.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000127.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000128.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000129.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000130.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000131.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000132.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000133.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000134.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000135.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000136.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000137.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000138.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000139.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000140.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000141.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000142.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000143.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000144.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000145.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000146.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000147.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000148.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000149.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000150.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000151.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000152.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000153.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000154.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000155.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000156.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000157.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000158.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000159.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000160.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000161.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000162.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000163.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000164.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000165.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000166.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000167.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000168.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000169.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000170.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000171.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000172.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000173.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000174.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000175.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000176.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000177.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000178.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000179.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000180.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000181.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000182.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000183.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000184.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000185.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000186.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000187.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000188.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000189.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000190.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000191.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000192.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000193.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000194.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000195.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000196.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000197.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000198.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000199.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000200.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000201.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000202.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000203.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000204.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000205.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000206.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000207.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000208.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000209.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000210.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000211.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000212.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000213.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000214.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000215.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000216.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000217.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000218.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000219.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000220.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000221.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000222.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000223.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000224.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000225.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000226.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000227.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000228.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000229.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000230.png
#  create mode 100644 cruce_test.gid/Rasters/Hydraulic/Processed/Depth_000231.png
# ...
#  create mode 100644 simulation_files/asc/Depth____175.0.asc
#  create mode 100644 simulation_files/asc/Depth____176.0.asc
#  create mode 100644 simulation_files/asc/Depth____177.0.asc
#  create mode 100644 simulation_files/asc/Depth____178.0.asc
#  create mode 100644 simulation_files/asc/Depth____179.0.asc
#  create mode 100644 simulation_files/asc/Depth____18.0.asc
#  create mode 100644 simulation_files/asc/Depth____180.0.asc
#  create mode 100644 simulation_files/asc/Depth____181.0.asc
#  create mode 100644 simulation_files/asc/Depth____182.0.asc
#  create mode 100644 simulation_files/asc/Depth____183.0.asc
#  create mode 100644 simulation_files/asc/Depth____184.0.asc
#  create mode 100644 simulation_files/asc/Depth____185.0.asc
#  create mode 100644 simulation_files/asc/Depth____186.0.asc
#  create mode 100644 simulation_files/asc/Depth____187.0.asc
#  create mode 100644 simulation_files/asc/Depth____188.0.asc
#  create mode 100644 simulation_files/asc/Depth____189.0.asc
#  create mode 100644 simulation_files/asc/Depth____19.0.asc
#  create mode 100644 simulation_files/asc/Depth____190.0.asc
#  create mode 100644 simulation_files/asc/Depth____191.0.asc
#  create mode 100644 simulation_files/asc/Depth____192.0.asc
#  create mode 100644 simulation_files/asc/Depth____193.0.asc
#  create mode 100644 simulation_files/asc/Depth____194.0.asc
#  create mode 100644 simulation_files/asc/Depth____195.0.asc
#  create mode 100644 simulation_files/asc/Depth____196.0.asc
#  create mode 100644 simulation_files/asc/Depth____197.0.asc
#  create mode 100644 simulation_files/asc/Depth____198.0.asc
#  create mode 100644 simulation_files/asc/Depth____199.0.asc
#  create mode 100644 simulation_files/asc/Depth____2.0.asc
#  create mode 100644 simulation_files/asc/Depth____20.0.asc
#  create mode 100644 simulation_files/asc/Depth____200.0.asc
#  create mode 100644 simulation_files/asc/Depth____201.0.asc
#  create mode 100644 simulation_files/asc/Depth____202.0.asc
#  create mode 100644 simulation_files/asc/Depth____203.0.asc
#  create mode 100644 simulation_files/asc/Depth____204.0.asc
#  create mode 100644 simulation_files/asc/Depth____205.0.asc
#  create mode 100644 simulation_files/asc/Depth____206.0.asc
#  create mode 100644 simulation_files/asc/Depth____207.0.asc
#  create mode 100644 simulation_files/asc/Depth____208.0.asc
#  create mode 100644 simulation_files/asc/Depth____209.0.asc
#  create mode 100644 simulation_files/asc/Depth____21.0.asc
#  create mode 100644 simulation_files/asc/Depth____210.0.asc
#  create mode 100644 simulation_files/asc/Depth____211.0.asc
#  create mode 100644 simulation_files/asc/Depth____212.0.asc
#  create mode 100644 simulation_files/asc/Depth____213.0.asc
#  create mode 100644 simulation_files/asc/Depth____214.0.asc
#  create mode 100644 simulation_files/asc/Depth____215.0.asc
#  create mode 100644 simulation_files/asc/Depth____216.0.asc
#  create mode 100644 simulation_files/asc/Depth____217.0.asc
#  create mode 100644 simulation_files/asc/Depth____218.0.asc
#  create mode 100644 simulation_files/asc/Depth____219.0.asc
#  create mode 100644 simulation_files/asc/Depth____22.0.asc
#  create mode 100644 simulation_files/asc/Depth____220.0.asc
#  create mode 100644 simulation_files/asc/Depth____221.0.asc
#  create mode 100644 simulation_files/asc/Depth____222.0.asc
#  create mode 100644 simulation_files/asc/Depth____223.0.asc
#  create mode 100644 simulation_files/asc/Depth____224.0.asc
#  create mode 100644 simulation_files/asc/Depth____225.0.asc
#  create mode 100644 simulation_files/asc/Depth____226.0.asc
#  create mode 100644 simulation_files/asc/Depth____227.0.asc
#  create mode 100644 simulation_files/asc/Depth____228.0.asc
#  create mode 100644 simulation_files/asc/Depth____229.0.asc
#  create mode 100644 simulation_files/asc/Depth____23.0.asc
#  create mode 100644 simulation_files/asc/Depth____230.0.asc
#  create mode 100644 simulation_files/asc/Depth____231.0.asc
#  create mode 100644 simulation_files/asc/Depth____232.0.asc
#  create mode 100644 simulation_files/asc/Depth____233.0.asc
#  create mode 100644 simulation_files/asc/Depth____234.0.asc
#  create mode 100644 simulation_files/asc/Depth____235.0.asc
#  create mode 100644 simulation_files/asc/Depth____236.0.asc
#  create mode 100644 simulation_files/asc/Depth____237.0.asc
#  create mode 100644 simulation_files/asc/Depth____238.0.asc
#  create mode 100644 simulation_files/asc/Depth____239.0.asc
#  create mode 100644 simulation_files/asc/Depth____24.0.asc
#  create mode 100644 simulation_files/asc/Depth____240.0.asc
#  create mode 100644 simulation_files/asc/Depth____241.0.asc
#  create mode 100644 simulation_files/asc/Depth____242.0.asc
#  create mode 100644 simulation_files/asc/Depth____243.0.asc
#  create mode 100644 simulation_files/asc/Depth____244.0.asc
#  create mode 100644 simulation_files/asc/Depth____245.0.asc
#  create mode 100644 simulation_files/asc/Depth____246.0.asc
#  create mode 100644 simulation_files/asc/Depth____247.0.asc
#  create mode 100644 simulation_files/asc/Depth____248.0.asc
#  create mode 100644 simulation_files/asc/Depth____249.0.asc
#  create mode 100644 simulation_files/asc/Depth____25.0.asc
#  create mode 100644 simulation_files/asc/Depth____250.0.asc
#  create mode 100644 simulation_files/asc/Depth____251.0.asc
#  create mode 100644 simulation_files/asc/Depth____252.0.asc
#  create mode 100644 simulation_files/asc/Depth____253.0.asc
#  create mode 100644 simulation_files/asc/Depth____254.0.asc
#  create mode 100644 simulation_files/asc/Depth____255.0.asc
#  create mode 100644 simulation_files/asc/Depth____256.0.asc
#  create mode 100644 simulation_files/asc/Depth____257.0.asc
#  create mode 100644 simulation_files/asc/Depth____258.0.asc
#  create mode 100644 simulation_files/asc/Depth____259.0.asc
#  create mode 100644 simulation_files/asc/Depth____26.0.asc
#  create mode 100644 simulation_files/asc/Depth____260.0.asc
#  create mode 100644 simulation_files/asc/Depth____261.0.asc
#  create mode 100644 simulation_files/asc/Depth____262.0.asc
#  create mode 100644 simulation_files/asc/Depth____263.0.asc
#  create mode 100644 simulation_files/asc/Depth____264.0.asc
#  create mode 100644 simulation_files/asc/Depth____265.0.asc
#  create mode 100644 simulation_files/asc/Depth____266.0.asc
#  create mode 100644 simulation_files/asc/Depth____267.0.asc
#  create mode 100644 simulation_files/asc/Depth____268.0.asc
#  create mode 100644 simulation_files/asc/Depth____269.0.asc
#  create mode 100644 simulation_files/asc/Depth____27.0.asc
#  create mode 100644 simulation_files/asc/Depth____270.0.asc
#  create mode 100644 simulation_files/asc/Depth____271.0.asc
#  create mode 100644 simulation_files/asc/Depth____272.0.asc
#  create mode 100644 simulation_files/asc/Depth____273.0.asc
#  create mode 100644 simulation_files/asc/Depth____274.0.asc
#  create mode 100644 simulation_files/asc/Depth____275.0.asc
#  create mode 100644 simulation_files/asc/Depth____276.0.asc
#  create mode 100644 simulation_files/asc/Depth____277.0.asc
#  create mode 100644 simulation_files/asc/Depth____278.0.asc
#  create mode 100644 simulation_files/asc/Depth____279.0.asc
#  create mode 100644 simulation_files/asc/Depth____28.0.asc
#  create mode 100644 simulation_files/asc/Depth____280.0.asc
#  create mode 100644 simulation_files/asc/Depth____281.0.asc
#  create mode 100644 simulation_files/asc/Depth____282.0.asc
#  create mode 100644 simulation_files/asc/Depth____283.0.asc
#  create mode 100644 simulation_files/asc/Depth____284.0.asc
#  create mode 100644 simulation_files/asc/Depth____285.0.asc
#  create mode 100644 simulation_files/asc/Depth____286.0.asc
#  create mode 100644 simulation_files/asc/Depth____287.0.asc
#  create mode 100644 simulation_files/asc/Depth____288.0.asc
#  create mode 100644 simulation_files/asc/Depth____289.0.asc
#  create mode 100644 simulation_files/asc/Depth____29.0.asc
#  create mode 100644 simulation_files/asc/Depth____290.0.asc
#  create mode 100644 simulation_files/asc/Depth____291.0.asc
#  create mode 100644 simulation_files/asc/Depth____292.0.asc
#  create mode 100644 simulation_files/asc/Depth____293.0.asc
#  create mode 100644 simulation_files/asc/Depth____294.0.asc
#  create mode 100644 simulation_files/asc/Depth____295.0.asc
#  create mode 100644 simulation_files/asc/Depth____296.0.asc
#  create mode 100644 simulation_files/asc/Depth____297.0.asc
#  create mode 100644 simulation_files/asc/Depth____298.0.asc
#  create mode 100644 simulation_files/asc/Depth____299.0.asc
#  create mode 100644 simulation_files/asc/Depth____3.0.asc
#  create mode 100644 simulation_files/asc/Depth____30.0.asc
#  create mode 100644 simulation_files/asc/Depth____300.0.asc
#  create mode 100644 simulation_files/asc/Depth____301.0.asc
#  create mode 100644 simulation_files/asc/Depth____302.0.asc
#  create mode 100644 simulation_files/asc/Depth____303.0.asc
#  create mode 100644 simulation_files/asc/Depth____304.0.asc
#  create mode 100644 simulation_files/asc/Depth____305.0.asc
#  create mode 100644 simulation_files/asc/Depth____306.0.asc
#  create mode 100644 simulation_files/asc/Depth____307.0.asc
#  create mode 100644 simulation_files/asc/Depth____308.0.asc
#  create mode 100644 simulation_files/asc/Depth____309.0.asc
#  create mode 100644 simulation_files/asc/Depth____31.0.asc
#  create mode 100644 simulation_files/asc/Depth____310.0.asc
#  create mode 100644 simulation_files/asc/Depth____311.0.asc
#  create mode 100644 simulation_files/asc/Depth____312.0.asc
#  create mode 100644 simulation_files/asc/Depth____313.0.asc
#  create mode 100644 simulation_files/asc/Depth____314.0.asc
#  create mode 100644 simulation_files/asc/Depth____315.0.asc
#  create mode 100644 simulation_files/asc/Depth____316.0.asc
#  create mode 100644 simulation_files/asc/Depth____317.0.asc
#  create mode 100644 simulation_files/asc/Depth____318.0.asc
#  create mode 100644 simulation_files/asc/Depth____319.0.asc
#  create mode 100644 simulation_files/asc/Depth____32.0.asc
#  create mode 100644 simulation_files/asc/Depth____320.0.asc
#  create mode 100644 simulation_files/asc/Depth____321.0.asc
#  create mode 100644 simulation_files/asc/Depth____322.0.asc
#  create mode 100644 simulation_files/asc/Depth____323.0.asc
#  create mode 100644 simulation_files/asc/Depth____324.0.asc
#  create mode 100644 simulation_files/asc/Depth____325.0.asc
#  create mode 100644 simulation_files/asc/Depth____326.0.asc
#  create mode 100644 simulation_files/asc/Depth____327.0.asc
#  create mode 100644 simulation_files/asc/Depth____328.0.asc
#  create mode 100644 simulation_files/asc/Depth____329.0.asc
#  create mode 100644 simulation_files/asc/Depth____33.0.asc
#  create mode 100644 simulation_files/asc/Depth____330.0.asc
#  create mode 100644 simulation_files/asc/Depth____331.0.asc
#  create mode 100644 simulation_files/asc/Depth____332.0.asc
#  create mode 100644 simulation_files/asc/Depth____333.0.asc
#  create mode 100644 simulation_files/asc/Depth____334.0.asc
#  create mode 100644 simulation_files/asc/Depth____335.0.asc
#  create mode 100644 simulation_files/asc/Depth____336.0.asc
#  create mode 100644 simulation_files/asc/Depth____337.0.asc
#  create mode 100644 simulation_files/asc/Depth____338.0.asc
#  create mode 100644 simulation_files/asc/Depth____339.0.asc
#  create mode 100644 simulation_files/asc/Depth____34.0.asc
#  create mode 100644 simulation_files/asc/Depth____340.0.asc
#  create mode 100644 simulation_files/asc/Depth____341.0.asc
#  create mode 100644 simulation_files/asc/Depth____342.0.asc
#  create mode 100644 simulation_files/asc/Depth____343.0.asc
#  create mode 100644 simulation_files/asc/Depth____344.0.asc
#  create mode 100644 simulation_files/asc/Depth____345.0.asc
#  create mode 100644 simulation_files/asc/Depth____346.0.asc
#  create mode 100644 simulation_files/asc/Depth____347.0.asc
#  create mode 100644 simulation_files/asc/Depth____348.0.asc
#  create mode 100644 simulation_files/asc/Depth____349.0.asc
#  create mode 100644 simulation_files/asc/Depth____35.0.asc
#  create mode 100644 simulation_files/asc/Depth____350.0.asc
#  create mode 100644 simulation_files/asc/Depth____36.0.asc
#  create mode 100644 simulation_files/asc/Depth____37.0.asc
#  create mode 100644 simulation_files/asc/Depth____38.0.asc
#  create mode 100644 simulation_files/asc/Depth____39.0.asc
#  create mode 100644 simulation_files/asc/Depth____4.0.asc
#  create mode 100644 simulation_files/asc/Depth____40.0.asc
#  create mode 100644 simulation_files/asc/Depth____41.0.asc
#  create mode 100644 simulation_files/asc/Depth____42.0.asc
#  create mode 100644 simulation_files/asc/Depth____43.0.asc
#  create mode 100644 simulation_files/asc/Depth____44.0.asc
#  create mode 100644 simulation_files/asc/Depth____45.0.asc
#  create mode 100644 simulation_files/asc/Depth____46.0.asc
#  create mode 100644 simulation_files/asc/Depth____47.0.asc
#  create mode 100644 simulation_files/asc/Depth____48.0.asc
#  create mode 100644 simulation_files/asc/Depth____49.0.asc
#  create mode 100644 simulation_files/asc/Depth____5.0.asc
#  create mode 100644 simulation_files/asc/Depth____50.0.asc
#  create mode 100644 simulation_files/asc/Depth____51.0.asc
#  create mode 100644 simulation_files/asc/Depth____52.0.asc
#  create mode 100644 simulation_files/asc/Depth____53.0.asc
#  create mode 100644 simulation_files/asc/Depth____54.0.asc
#  create mode 100644 simulation_files/asc/Depth____55.0.asc
#  create mode 100644 simulation_files/asc/Depth____56.0.asc
#  create mode 100644 simulation_files/asc/Depth____57.0.asc
#  create mode 100644 simulation_files/asc/Depth____58.0.asc
#  create mode 100644 simulation_files/asc/Depth____59.0.asc
#  create mode 100644 simulation_files/asc/Depth____6.0.asc
#  create mode 100644 simulation_files/asc/Depth____60.0.asc
#  create mode 100644 simulation_files/asc/Depth____61.0.asc
#  create mode 100644 simulation_files/asc/Depth____62.0.asc
#  create mode 100644 simulation_files/asc/Depth____63.0.asc
#  create mode 100644 simulation_files/asc/Depth____64.0.asc
#  create mode 100644 simulation_files/asc/Depth____65.0.asc
#  create mode 100644 simulation_files/asc/Depth____66.0.asc
#  create mode 100644 simulation_files/asc/Depth____67.0.asc
#  create mode 100644 simulation_files/asc/Depth____68.0.asc
#  create mode 100644 simulation_files/asc/Depth____69.0.asc
#  create mode 100644 simulation_files/asc/Depth____7.0.asc
#  create mode 100644 simulation_files/asc/Depth____70.0.asc
#  create mode 100644 simulation_files/asc/Depth____71.0.asc
#  create mode 100644 simulation_files/asc/Depth____72.0.asc
#  create mode 100644 simulation_files/asc/Depth____73.0.asc
#  create mode 100644 simulation_files/asc/Depth____74.0.asc
#  create mode 100644 simulation_files/asc/Depth____75.0.asc
#  create mode 100644 simulation_files/asc/Depth____76.0.asc
#  create mode 100644 simulation_files/asc/Depth____77.0.asc
#  create mode 100644 simulation_files/asc/Depth____78.0.asc
#  create mode 100644 simulation_files/asc/Depth____79.0.asc
#  create mode 100644 simulation_files/asc/Depth____8.0.asc
#  create mode 100644 simulation_files/asc/Depth____80.0.asc
#  create mode 100644 simulation_files/asc/Depth____81.0.asc
#  create mode 100644 simulation_files/asc/Depth____82.0.asc
#  create mode 100644 simulation_files/asc/Depth____83.0.asc
#  create mode 100644 simulation_files/asc/Depth____84.0.asc
#  create mode 100644 simulation_files/asc/Depth____85.0.asc
#  create mode 100644 simulation_files/asc/Depth____86.0.asc
#  create mode 100644 simulation_files/asc/Depth____87.0.asc
#  create mode 100644 simulation_files/asc/Depth____88.0.asc
#  create mode 100644 simulation_files/asc/Depth____89.0.asc
#  create mode 100644 simulation_files/asc/Depth____9.0.asc
#  create mode 100644 simulation_files/asc/Depth____90.0.asc
#  create mode 100644 simulation_files/asc/Depth____91.0.asc
#  create mode 100644 simulation_files/asc/Depth____92.0.asc
#  create mode 100644 simulation_files/asc/Depth____93.0.asc
#  create mode 100644 simulation_files/asc/Depth____94.0.asc
#  create mode 100644 simulation_files/asc/Depth____95.0.asc
#  create mode 100644 simulation_files/asc/Depth____96.0.asc
#  create mode 100644 simulation_files/asc/Depth____97.0.asc
#  create mode 100644 simulation_files/asc/Depth____98.0.asc
#  create mode 100644 simulation_files/asc/Depth____99.0.asc
# To https://github.com/cgotelli/Floods-WebMap.git
#    5f17333..732fb1a  main -> main

# %% [markdown]
# ---

# %% [markdown]
# Original aquí abajo

# %% [markdown]
# ```python
# # -*- coding: utf-8 -*-
# """
# Código para ejecutar varios modelos de Iber en serie
#
# Gonzalo García-Alén Julio/2023
# """
#
# import os
# import sys
# import subprocess
#
# # Aquí indicamos la ruta de los modelos que queremos que sean ejecutados
# ModelosIber = [r'E:\te7.gid', r'E:\te8.gid']
#
# # Especificamos el ejecutable a usar, que ya debe estar en cada carpeta .gid
# # Todos los ejecutables de Iber están en esta ruta dentro de la carpeta donde
# # se ha instalado el programa: ...\Iber 3.3\problemtypes\IBER.gid\bin\windows
# iber_exe = r'C:\Program Files\Iber\Iber 3.3.1\problemtypes\IBER.gid\bin\windows\IberPlus.exe'  # 'Iber.exe', 'IberPlus.exe' o 'RIber.exe'
#
#
# print('\tEjecutando modelos Iber:')
# for i in range(len(ModelosIber)):
#     os.chdir(ModelosIber[i])
#     a = ('\t' + str(i+1) + '/' + str(len(ModelosIber)))
#     sys.stdout.write('\r'+a)
#     subprocess.call( iber_exe )
#     if i == (len(ModelosIber)-1): print('\n')
#     print('done')
# ```
